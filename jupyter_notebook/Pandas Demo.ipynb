# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv')
# Out:
# C:\Users\Tag ElMaaly\AppData\Local\Temp\ipykernel_6232\2720419680.py:1: DtypeWarning: Columns (56,74,92,97,98,105,109,110,132,162,165) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/survey_results_public.csv')

# %%
df.head(30)
# Out:
#     ResponseId                                         MainBranch  \
# 0            1                     I am a developer by profession
# 1            2                     I am a developer by profession
# 2            3                     I am a developer by profession
# 3            4                     I am a developer by profession
# 4            5                     I am a developer by profession
# 5            6                     I am a developer by profession
# 6            7                     I am a developer by profession
# 7            8                     I am a developer by profession
# 8            9                     I am a developer by profession
# 9           10                     I am a developer by profession
# 10          11                     I am a developer by profession
# 11          12                     I am a developer by profession
# 12          13                     I am a developer by profession
# 13          14                     I am a developer by profession
# 14          15                     I am a developer by profession
# 15          16                     I am a developer by profession
# 16          17  I am not primarily a developer, but I write co...
# 17          18                     I am a developer by profession
# 18          19                     I am a developer by profession
# 19          20  I am not primarily a developer, but I write co...
# 20          21  I am not primarily a developer, but I write co...
# 21          22  I am not primarily a developer, but I write co...
# 22          23                     I am a developer by profession
# 23          24                     I am a developer by profession
# 24          25                     I am a developer by profession
# 25          26                     I am a developer by profession
# 26          27                     I am a developer by profession
# 27          28                     I am a developer by profession
# 28          29                     I am a developer by profession
# 29          30                     I am a developer by profession
#
#                   Age                                            EdLevel  \
# 0     25-34 years old    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1     25-34 years old                Associate degree (A.A., A.S., etc.)
# 2     35-44 years old       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3     35-44 years old       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4     35-44 years old    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 5     45-54 years old    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 6     25-34 years old  Some college/university study without earning ...
# 7     35-44 years old     Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 8     25-34 years old       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 9     25-34 years old    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 10    25-34 years old    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 11    18-24 years old       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 12    35-44 years old       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 13    25-34 years old       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 14    35-44 years old     Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 15    18-24 years old       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 16  65 years or older  Some college/university study without earning ...
# 17    25-34 years old    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 18    35-44 years old                Associate degree (A.A., A.S., etc.)
# 19    25-34 years old    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 20    55-64 years old     Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 21    45-54 years old  Some college/university study without earning ...
# 22    25-34 years old  Some college/university study without earning ...
# 23    18-24 years old       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 24  65 years or older  Some college/university study without earning ...
# 25    55-64 years old       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 26    45-54 years old    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 27    45-54 years old       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 28    35-44 years old     Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 29    35-44 years old    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                            Employment  \
# 0                                            Employed
# 1                                            Employed
# 2   Independent contractor, freelancer, or self-em...
# 3                                            Employed
# 4   Independent contractor, freelancer, or self-em...
# 5   Independent contractor, freelancer, or self-em...
# 6   Independent contractor, freelancer, or self-em...
# 7                                            Employed
# 8                                            Employed
# 9                                            Employed
# 10                                           Employed
# 11                                           Employed
# 12  Independent contractor, freelancer, or self-em...
# 13                                           Employed
# 14                                           Employed
# 15                                            Student
# 16                                            Retired
# 17                                           Employed
# 18                                           Employed
# 19  Independent contractor, freelancer, or self-em...
# 20                                           Employed
# 21                                           Employed
# 22                                           Employed
# 23                                           Employed
# 24  Independent contractor, freelancer, or self-em...
# 25  Independent contractor, freelancer, or self-em...
# 26  Independent contractor, freelancer, or self-em...
# 27                                           Employed
# 28  Independent contractor, freelancer, or self-em...
# 29                                           Employed
#
#                                        EmploymentAddl  WorkExp  \
# 0     Caring for dependents (children, elderly, etc.)      8.0
# 1                                                 NaN      2.0
# 2                                   None of the above     10.0
# 3                                   None of the above      4.0
# 4     Caring for dependents (children, elderly, etc.)     21.0
# 5   Caring for dependents (children, elderly, etc....     15.0
# 6                                   None of the above      9.0
# 7   Engaged in paid work (20-29 hours per week);Tr...     22.0
# 8   Caring for dependents (children, elderly, etc....      9.0
# 9                                   None of the above      7.0
# 10                                  None of the above      7.0
# 11                                  None of the above      3.0
# 12    Caring for dependents (children, elderly, etc.)     10.0
# 13    Caring for dependents (children, elderly, etc.)      6.0
# 14  Attending school (full-time);Attending school ...     15.0
# 15  Engaged in paid work (20-29 hours per week);En...      5.0
# 16                                  None of the above     20.0
# 17                                                NaN      1.0
# 18                                                NaN     20.0
# 19  Engaged in paid work (less than 10 hours per w...      3.0
# 20                                  None of the above     40.0
# 21                                  None of the above     35.0
# 22                                  None of the above      7.0
# 23                                  None of the above      2.0
# 24  Transitioning to retirement (gradually reducin...     40.0
# 25                                  None of the above     37.0
# 26                                  None of the above     26.0
# 27    Caring for dependents (children, elderly, etc.)     24.0
# 28        Engaged in paid work (20-29 hours per week)     13.0
# 29        Engaged in paid work (10-19 hours per week)     19.0
#
#                                       LearnCodeChoose  \
# 0   Yes, I am not new to coding but am learning ne...
# 1   Yes, I am not new to coding but am learning ne...
# 2   Yes, I am not new to coding but am learning ne...
# 3   Yes, I am not new to coding but am learning ne...
# 4   No, I am not new to coding and did not learn n...
# 5   Yes, I am not new to coding but am learning ne...
# 6   Yes, I am not new to coding but am learning ne...
# 7   Yes, I am not new to coding but am learning ne...
# 8   Yes, I am not new to coding but am learning ne...
# 9   Yes, I am not new to coding but am learning ne...
# 10  No, I am not new to coding and did not learn n...
# 11  No, I am not new to coding and did not learn n...
# 12  Yes, I am not new to coding but am learning ne...
# 13  Yes, I am not new to coding but am learning ne...
# 14  No, I am not new to coding and did not learn n...
# 15     Yes, I am new to coding or currently a student
# 16  No, I am not new to coding and did not learn n...
# 17  Yes, I am not new to coding but am learning ne...
# 18  Yes, I am not new to coding but am learning ne...
# 19  Yes, I am not new to coding but am learning ne...
# 20  Yes, I am not new to coding but am learning ne...
# 21  Yes, I am not new to coding but am learning ne...
# 22  Yes, I am not new to coding but am learning ne...
# 23  Yes, I am not new to coding but am learning ne...
# 24  No, I am not new to coding and did not learn n...
# 25  Yes, I am not new to coding but am learning ne...
# 26  Yes, I am not new to coding but am learning ne...
# 27  No, I am not new to coding and did not learn n...
# 28  Yes, I am not new to coding but am learning ne...
# 29  Yes, I am not new to coding but am learning ne...
#
#                                             LearnCode  \
# 0   Online Courses or Certification (includes all ...
# 1   Online Courses or Certification (includes all ...
# 2   Online Courses or Certification (includes all ...
# 3   Other online resources (e.g. standard search, ...
# 4                                                 NaN
# 5   Online Courses or Certification (includes all ...
# 6   Videos (not associated with specific online co...
# 7   Books / Physical media;Technical documentation...
# 8   Online Courses or Certification (includes all ...
# 9   Other online resources (e.g. standard search, ...
# 10                                                NaN
# 11                                                NaN
# 12  Videos (not associated with specific online co...
# 13  Online Courses or Certification (includes all ...
# 14                                                NaN
# 15  Online Courses or Certification (includes all ...
# 16                                                NaN
# 17  Online Courses or Certification (includes all ...
# 18  Stack Overflow or Stack Exchange;Technical doc...
# 19  Videos (not associated with specific online co...
# 20  Other online resources (e.g. standard search, ...
# 21  Other online resources (e.g. standard search, ...
# 22  Other online resources (e.g. standard search, ...
# 23  Other online resources (e.g. standard search, ...
# 24                                                NaN
# 25  Stack Overflow or Stack Exchange;Technical doc...
# 26  Online Courses or Certification (includes all ...
# 27                                                NaN
# 28  Online Courses or Certification (includes all ...
# 29  Other online resources (e.g. standard search, ...
#
#                                           LearnCodeAI  \
# 0   Yes, I learned how to use AI-enabled tools for...
# 1   Yes, I learned how to use AI-enabled tools for...
# 2   Yes, I learned how to use AI-enabled tools for...
# 3   Yes, I learned how to use AI-enabled tools for...
# 4   Yes, I learned how to use AI-enabled tools for...
# 5   Yes, I learned how to use AI-enabled tools req...
# 6   Yes, I learned how to use AI-enabled tools for...
# 7   Yes, I learned how to use AI-enabled tools for...
# 8   Yes, I learned how to use AI-enabled tools for...
# 9   No, I learned something that was not related t...
# 10  Yes, I learned how to use AI-enabled tools for...
# 11  Yes, I learned how to use AI-enabled tools for...
# 12  No, I learned something that was not related t...
# 13  Yes, I learned how to use AI-enabled tools req...
# 14  No, I learned something that was not related t...
# 15  No, I learned something that was not related t...
# 16  No, I didn't spend time learning in the past year
# 17  Yes, I learned how to use AI-enabled tools for...
# 18  No, I didn't spend time learning in the past year
# 19  Yes, I learned how to use AI-enabled tools for...
# 20  No, I learned something that was not related t...
# 21  No, I didn't spend time learning in the past year
# 22  Yes, I learned how to use AI-enabled tools req...
# 23  No, I learned something that was not related t...
# 24  No, I learned something that was not related t...
# 25  Yes, I learned how to use AI-enabled tools for...
# 26  Yes, I learned how to use AI-enabled tools for...
# 27  Yes, I learned how to use AI-enabled tools for...
# 28  Yes, I learned how to use AI-enabled tools req...
# 29  Yes, I learned how to use AI-enabled tools req...
#
#                                            AILearnHow  YearsCode  \
# 0                 AI CodeGen tools or AI-enabled apps       14.0
# 1                 AI CodeGen tools or AI-enabled apps       10.0
# 2   AI CodeGen tools or AI-enabled apps;Technical ...       12.0
# 3   AI CodeGen tools or AI-enabled apps;Videos (no...        5.0
# 4   Technical documentation (is generated for/by t...       22.0
# 5   Technical documentation (is generated for/by t...       20.0
# 6   AI CodeGen tools or AI-enabled apps;Videos (no...       13.0
# 7   AI CodeGen tools or AI-enabled apps;Blogs or p...       30.0
# 8   Technical documentation (is generated for/by t...       15.0
# 9                                                 NaN       10.0
# 10  AI CodeGen tools or AI-enabled apps;Technical ...        9.0
# 11  Videos (not associated with specific online co...        5.0
# 12                                                NaN       10.0
# 13  AI CodeGen tools or AI-enabled apps;Other onli...        6.0
# 14                                                NaN        NaN
# 15                                                NaN        3.0
# 16                                                NaN       40.0
# 17  Videos (not associated with specific online co...        8.0
# 18                                                NaN       20.0
# 19  AI CodeGen tools or AI-enabled apps;Videos (no...        6.0
# 20                                                NaN       45.0
# 21                                                NaN       35.0
# 22                   Colleague or on-the-job training       11.0
# 23                                                NaN        7.0
# 24                                                NaN       47.0
# 25  AI CodeGen tools or AI-enabled apps;Blogs or p...       41.0
# 26  Technical documentation (is generated for/by t...       30.0
# 27                                                NaN       36.0
# 28  Technical documentation (is generated for/by t...       13.0
# 29  AI CodeGen tools or AI-enabled apps;Technical ...       15.0
#
#                                         DevType                   OrgSize  \
# 0                             Developer, mobile        20 to 99 employees
# 1                           Developer, back-end      500 to 999 employees
# 2                          Developer, front-end                       NaN
# 3                           Developer, back-end  10,000 or more employees
# 4                           Engineering manager                       NaN
# 5                           Developer, back-end                       NaN
# 6                         Developer, full-stack                       NaN
# 7              Architect, software or solutions    Less than 20 employees
# 8                                 Data engineer  5,000 to 9,999 employees
# 9                             Developer, mobile        20 to 99 employees
# 10                          Developer, back-end      100 to 499 employees
# 11                          Developer, back-end      100 to 499 employees
# 12                         Developer, front-end                       NaN
# 13                        Developer, full-stack  1,000 to 4,999 employees
# 14             Architect, software or solutions        20 to 99 employees
# 15                            Developer, mobile        20 to 99 employees
# 16                Financial analyst or engineer                       NaN
# 17                        Developer, full-stack      100 to 499 employees
# 18                          Developer, back-end        20 to 99 employees
# 19                          Academic researcher              I don’t know
# 20                          Academic researcher      100 to 499 employees
# 21                          Academic researcher              I don’t know
# 22                        Developer, full-stack      100 to 499 employees
# 23  Developer, embedded applications or devices    Less than 20 employees
# 24                          Developer, back-end                       NaN
# 25                        Developer, full-stack                       NaN
# 26                        Developer, full-stack                       NaN
# 27                        Developer, full-stack  1,000 to 4,999 employees
# 28                        Developer, full-stack    Less than 20 employees
# 29                            Developer, mobile      500 to 999 employees
#
#                     ICorPM                                         RemoteWork  \
# 0           People manager                                             Remote
# 1   Individual contributor  Hybrid (some in-person, leans heavy to flexibi...
# 2                      NaN                                                NaN
# 3   Individual contributor                                             Remote
# 4                      NaN                                                NaN
# 5                      NaN                                                NaN
# 6                      NaN                                                NaN
# 7           People manager                                             Remote
# 8   Individual contributor                                             Remote
# 9   Individual contributor                                             Remote
# 10  Individual contributor                                             Remote
# 11  Individual contributor                                             Remote
# 12                     NaN                                                NaN
# 13          People manager                                          In-person
# 14          People manager                                             Remote
# 15  Individual contributor                                             Remote
# 16                     NaN                                                NaN
# 17  Individual contributor     Hybrid (some remote, leans heavy to in-person)
# 18          People manager     Hybrid (some remote, leans heavy to in-person)
# 19  Individual contributor     Hybrid (some remote, leans heavy to in-person)
# 20  Individual contributor  Your choice (very flexible, you can come in wh...
# 21          People manager  Your choice (very flexible, you can come in wh...
# 22  Individual contributor                                             Remote
# 23  Individual contributor                                             Remote
# 24                     NaN                                                NaN
# 25                     NaN                                                NaN
# 26                     NaN                                                NaN
# 27  Individual contributor     Hybrid (some remote, leans heavy to in-person)
# 28  Individual contributor                                             Remote
# 29  Individual contributor                                             Remote
#
#                                     PurchaseInfluence  TechEndorseIntro  \
# 0   Yes, I influenced the purchase of a substantia...              Work
# 1                                                  No  Personal Project
# 2                                                  No              Work
# 3                                                  No  Personal Project
# 4   Yes, I endorsed a tool that was open-source an...              Work
# 5   Yes, I influenced the purchase of a substantia...              Work
# 6                                                  No  Personal Project
# 7   Yes, I influenced the purchase of a substantia...  Personal Project
# 8   Yes, I influenced the purchase of a tool that ...  Personal Project
# 9                                                  No              Work
# 10  Yes, I influenced the purchase of a tool that ...              Work
# 11                                                 No               NaN
# 12                                                 No  Personal Project
# 13  Yes, I influenced the purchase of a substantia...               NaN
# 14                                                 No  Personal Project
# 15  Yes, I endorsed a tool that was open-source an...              Work
# 16                                                NaN  Personal Project
# 17  Yes, I endorsed a tool that was open-source an...              Work
# 18  Yes, I influenced the purchase of a substantia...              Work
# 19                                                 No  Personal Project
# 20                                                 No               NaN
# 21                                                 No              Work
# 22  Yes, I influenced the purchase of a tool that ...              Work
# 23  Yes, I endorsed a tool that was open-source an...              Work
# 24                                                 No  Personal Project
# 25  Yes, I influenced the purchase of a substantia...  Personal Project
# 26  Yes, I influenced the purchase of a tool that ...              Work
# 27                                                 No              Work
# 28                                                 No              Work
# 29  Yes, I influenced the purchase of a tool that ...              Work
#
#     TechEndorse_1  TechEndorse_2  TechEndorse_3  TechEndorse_4  TechEndorse_5  \
# 0            10.0            7.0            9.0            6.0            3.0
# 1            13.0            1.0            2.0            9.0            4.0
# 2            12.0            2.0            3.0            7.0            5.0
# 3             2.0           12.0            6.0            5.0           13.0
# 4             6.0            3.0            1.0            9.0           10.0
# 5            12.0            5.0            4.0            6.0            2.0
# 6            11.0            1.0            2.0            6.0            4.0
# 7            12.0            2.0            1.0           10.0            4.0
# 8             5.0            7.0           13.0            4.0            9.0
# 9            13.0            2.0            5.0            1.0            6.0
# 10           11.0            4.0            5.0           13.0            7.0
# 11            NaN            NaN            NaN            NaN            NaN
# 12            6.0           13.0           11.0            1.0            2.0
# 13            9.0            2.0            8.0           13.0           11.0
# 14            9.0            7.0            4.0           11.0            3.0
# 15            9.0            3.0            6.0            7.0            2.0
# 16            7.0           12.0            2.0           11.0            5.0
# 17           12.0            3.0            4.0            5.0            1.0
# 18           14.0            6.0            5.0            1.0            2.0
# 19           12.0            2.0            3.0           13.0            5.0
# 20            NaN            NaN            NaN            NaN            NaN
# 21           12.0           13.0            9.0           10.0            4.0
# 22           13.0            3.0            9.0           10.0            1.0
# 23           14.0            5.0            1.0            7.0            8.0
# 24            9.0            6.0            2.0            3.0           13.0
# 25            7.0            5.0            4.0            2.0            1.0
# 26           12.0           10.0            3.0           11.0            2.0
# 27           12.0            1.0            9.0            7.0            4.0
# 28           12.0            2.0            1.0            3.0           10.0
# 29            9.0            3.0            4.0            8.0           11.0
#
#     TechEndorse_6  TechEndorse_7  TechEndorse_8  TechEndorse_9  \
# 0            11.0           12.0            1.0            8.0
# 1             3.0           12.0            5.0            7.0
# 2            10.0           13.0            1.0            4.0
# 3             3.0            8.0           11.0            7.0
# 4             8.0            7.0            4.0            2.0
# 5            10.0            3.0            7.0            8.0
# 6             7.0           13.0            8.0            3.0
# 7             5.0            8.0            6.0            7.0
# 8             8.0           12.0            2.0           11.0
# 9             9.0           10.0            7.0            4.0
# 10            8.0            2.0            3.0           10.0
# 11            NaN            NaN            NaN            NaN
# 12           10.0            7.0            9.0            5.0
# 13            6.0            3.0           10.0            5.0
# 14            8.0            2.0           12.0            6.0
# 15            8.0            1.0            4.0            5.0
# 16           10.0            6.0            9.0            3.0
# 17            2.0            9.0            7.0           11.0
# 18            4.0           12.0            3.0           10.0
# 19            7.0            8.0            4.0            6.0
# 20            NaN            NaN            NaN            NaN
# 21           11.0            8.0            7.0            3.0
# 22           11.0            4.0            2.0            5.0
# 23            6.0            2.0           11.0            9.0
# 24            8.0            7.0            5.0            1.0
# 25            8.0            3.0            6.0           13.0
# 26            8.0            5.0            6.0            1.0
# 27           13.0            5.0            6.0            3.0
# 28            8.0            4.0           11.0            6.0
# 29            7.0            5.0            1.0           10.0
#
#     TechEndorse_13 TechEndorse_13_TEXT  TechOppose_1  TechOppose_2  \
# 0             14.0                 NaN          15.0           7.0
# 1             14.0                 NaN          14.0           1.0
# 2             14.0                 NaN           8.0           1.0
# 3             14.0                 NaN          10.0           5.0
# 4             14.0                 NaN           7.0          13.0
# 5             14.0                 NaN          12.0           5.0
# 6             14.0                 NaN           8.0           3.0
# 7             14.0                 NaN          14.0           3.0
# 8             14.0                 NaN          11.0          13.0
# 9             14.0                 NaN          14.0           1.0
# 10            14.0                 NaN           NaN           NaN
# 11             NaN                 NaN           NaN           NaN
# 12            14.0                 NaN           NaN           NaN
# 13            14.0                 NaN           3.0           8.0
# 14            14.0                 NaN           2.0           6.0
# 15            14.0                 NaN           7.0           4.0
# 16            14.0         usefullness           4.0          10.0
# 17            14.0                 NaN          11.0           6.0
# 18            11.0                 NaN           NaN           NaN
# 19            14.0                 NaN           9.0          13.0
# 20             NaN                 NaN           NaN           NaN
# 21            14.0                 NaN          15.0          12.0
# 22            14.0                 NaN          14.0           2.0
# 23            13.0                 NaN          15.0           9.0
# 24            14.0                 NaN           6.0           3.0
# 25            14.0                 NaN          11.0           2.0
# 26            14.0                 NaN          12.0           6.0
# 27            14.0                 NaN          14.0           7.0
# 28            14.0                 NaN           4.0          10.0
# 29            14.0                 NaN          12.0           4.0
#
#     TechOppose_3  TechOppose_5  TechOppose_7  TechOppose_9  TechOppose_11  \
# 0            8.0          12.0          11.0           1.0            6.0
# 1           13.0          10.0           9.0           3.0            4.0
# 2            2.0          12.0          13.0           3.0            9.0
# 3            8.0           4.0          13.0          12.0            2.0
# 4            3.0           9.0          12.0           6.0            1.0
# 5           13.0          10.0           9.0           1.0            4.0
# 6           14.0          11.0           4.0           1.0           10.0
# 7            4.0           9.0           1.0           5.0            2.0
# 8           10.0           1.0           5.0           9.0            7.0
# 9            9.0          10.0           8.0           5.0            2.0
# 10           NaN           NaN           NaN           NaN            NaN
# 11           NaN           NaN           NaN           NaN            NaN
# 12           NaN           NaN           NaN           NaN            NaN
# 13           5.0          13.0          14.0          10.0            2.0
# 14          10.0           3.0           1.0           5.0            9.0
# 15           8.0          14.0           5.0          12.0            3.0
# 16           5.0           1.0          12.0          13.0            3.0
# 17           9.0          14.0           8.0           2.0            5.0
# 18           NaN           NaN           NaN           NaN            NaN
# 19           4.0           3.0           1.0          14.0           10.0
# 20           NaN           NaN           NaN           NaN            NaN
# 21          13.0           4.0           8.0           1.0            2.0
# 22           8.0          12.0           4.0           1.0           13.0
# 23           3.0           7.0          10.0           6.0            1.0
# 24           9.0          10.0           2.0           8.0           12.0
# 25           8.0           5.0           6.0           4.0            1.0
# 26           7.0           1.0           2.0           9.0            4.0
# 27          12.0          10.0           6.0           3.0            2.0
# 28          11.0           6.0           7.0           3.0           14.0
# 29           5.0           9.0          14.0           7.0           11.0
#
#     TechOppose_13  TechOppose_16  TechOppose_15 TechOppose_15_TEXT  \
# 0            13.0            3.0           16.0                NaN
# 1             2.0            5.0           15.0                NaN
# 2             4.0           11.0           15.0                NaN
# 3             7.0            1.0           15.0                NaN
# 4             8.0           14.0           15.0                NaN
# 5             6.0            2.0           15.0                NaN
# 6             5.0           13.0           15.0                NaN
# 7            11.0           12.0           15.0                NaN
# 8             8.0            2.0           15.0                NaN
# 9             3.0           12.0           15.0                NaN
# 10            NaN            NaN            NaN                NaN
# 11            NaN            NaN            NaN                NaN
# 12            NaN            NaN            NaN                NaN
# 13            7.0            6.0           15.0                NaN
# 14           12.0            8.0           15.0                NaN
# 15           13.0            9.0           15.0                NaN
# 16            2.0           11.0           15.0                NaN
# 17            1.0            4.0           15.0                NaN
# 18            NaN            NaN            NaN                NaN
# 19            6.0            2.0           15.0                NaN
# 20            NaN            NaN            NaN                NaN
# 21            7.0            9.0           14.0                NaN
# 22           10.0            3.0           15.0                NaN
# 23            8.0            5.0           14.0                NaN
# 24            4.0           14.0            1.0                 AI
# 25            3.0            9.0           15.0                NaN
# 26            8.0           11.0           15.0                NaN
# 27            8.0            1.0           15.0                NaN
# 28            1.0           13.0           15.0                NaN
# 29            6.0            2.0           15.0                NaN
#
#                         Industry  JobSatPoints_1  ...  SO_Actions_10  \
# 0                        Fintech             3.0  ...           11.0
# 1   Retail and Consumer Services            10.0  ...           11.0
# 2           Software Development             9.0  ...           11.0
# 3   Retail and Consumer Services             1.0  ...           11.0
# 4           Software Development             9.0  ...           12.0
# 5                        Fintech             4.0  ...           11.0
# 6                      Insurance             4.0  ...            NaN
# 7           Software Development             7.0  ...           11.0
# 8     Banking/Financial Services             1.0  ...           11.0
# 9           Software Development             NaN  ...            NaN
# 10                       Fintech             6.0  ...           11.0
# 11                       Fintech             1.0  ...            NaN
# 12          Software Development             6.0  ...           11.0
# 13                       Fintech             8.0  ...            NaN
# 14                       Fintech             3.0  ...            NaN
# 15          Software Development             1.0  ...            NaN
# 16                           NaN             NaN  ...            6.0
# 17                    Government             1.0  ...           14.0
# 18                       Fintech             4.0  ...            NaN
# 19                        Energy             NaN  ...           14.0
# 20              Higher Education             NaN  ...           13.0
# 21              Higher Education             NaN  ...            7.0
# 22                       Fintech             3.0  ...            9.0
# 23          Software Development             3.0  ...           14.0
# 24          Software Development             2.0  ...            NaN
# 25          Software Development             2.0  ...           13.0
# 26          Software Development             1.0  ...           14.0
# 27    Banking/Financial Services             1.0  ...            7.0
# 28  Media & Advertising Services             1.0  ...           11.0
# 29          Software Development             7.0  ...            8.0
#
#     SO_Actions_15          SO_Actions_15_TEXT           SOComm  \
# 0            15.0                         NaN          Neutral
# 1            15.0                         NaN    Yes, somewhat
# 2            15.0                         NaN          Neutral
# 3            15.0                         NaN          Neutral
# 4            15.0                         NaN   No, not really
# 5            15.0                         NaN    Yes, somewhat
# 6             NaN                         NaN              NaN
# 7            15.0                         NaN  Yes, definitely
# 8            15.0                         NaN              NaN
# 9             NaN                         NaN   No, not really
# 10           15.0                         NaN    Yes, somewhat
# 11            NaN                         NaN   No, not at all
# 12           15.0                         NaN   No, not really
# 13            NaN                         NaN              NaN
# 14            NaN                         NaN          Neutral
# 15            NaN                         NaN  Yes, definitely
# 16           15.0  I don't use stsck overflow   No, not at all
# 17           15.0                         NaN   No, not really
# 18            NaN                         NaN   No, not at all
# 19           15.0                         NaN   No, not at all
# 20           15.0                         NaN  Yes, definitely
# 21            2.0                         NaN   No, not at all
# 22           15.0                         NaN  Yes, definitely
# 23           15.0                         NaN          Neutral
# 24            NaN                         NaN   No, not at all
# 25           15.0                         NaN    Yes, somewhat
# 26           15.0                         NaN    Yes, somewhat
# 27           15.0                         NaN  Yes, definitely
# 28           15.0                         NaN          Neutral
# 29           15.0                         NaN   No, not really
#
#                             SOFriction  \
# 0                 Rarely, almost never
# 1               About half of the time
# 2               About half of the time
# 3                 Rarely, almost never
# 4                 Rarely, almost never
# 5                 Rarely, almost never
# 6                                  NaN
# 7               About half of the time
# 8                                  NaN
# 9   I don't use AI or AI-enabled tools
# 10              About half of the time
# 11          Less than half of the time
# 12          Less than half of the time
# 13                                 NaN
# 14              About half of the time
# 15              About half of the time
# 16  I don't use AI or AI-enabled tools
# 17              About half of the time
# 18  I don't use AI or AI-enabled tools
# 19  I don't use AI or AI-enabled tools
# 20  I don't use AI or AI-enabled tools
# 21  I don't use AI or AI-enabled tools
# 22                Rarely, almost never
# 23  I don't use AI or AI-enabled tools
# 24  I don't use AI or AI-enabled tools
# 25                Rarely, almost never
# 26                Rarely, almost never
# 27                Rarely, almost never
# 28                Rarely, almost never
# 29              About half of the time
#
#                                        AISelect            AISent  \
# 0   Yes, I use AI tools monthly or infrequently       Indifferent
# 1                    Yes, I use AI tools weekly       Indifferent
# 2                     Yes, I use AI tools daily         Favorable
# 3                    Yes, I use AI tools weekly         Favorable
# 4                    Yes, I use AI tools weekly         Favorable
# 5                     Yes, I use AI tools daily       Indifferent
# 6                     Yes, I use AI tools daily         Favorable
# 7                     Yes, I use AI tools daily    Very favorable
# 8   Yes, I use AI tools monthly or infrequently       Indifferent
# 9                       No, and I don't plan to       Unfavorable
# 10                    Yes, I use AI tools daily    Very favorable
# 11                    Yes, I use AI tools daily    Very favorable
# 12  Yes, I use AI tools monthly or infrequently       Unfavorable
# 13                                          NaN               NaN
# 14                    Yes, I use AI tools daily         Favorable
# 15                    Yes, I use AI tools daily         Favorable
# 16                      No, and I don't plan to  Very unfavorable
# 17                    Yes, I use AI tools daily       Unfavorable
# 18                      No, and I don't plan to  Very unfavorable
# 19                    Yes, I use AI tools daily    Very favorable
# 20                      No, and I don't plan to       Unfavorable
# 21                      No, and I don't plan to  Very unfavorable
# 22  Yes, I use AI tools monthly or infrequently       Unfavorable
# 23                      No, and I don't plan to  Very unfavorable
# 24                      No, and I don't plan to  Very unfavorable
# 25                    Yes, I use AI tools daily         Favorable
# 26                    Yes, I use AI tools daily         Favorable
# 27                    Yes, I use AI tools daily       Indifferent
# 28                   Yes, I use AI tools weekly         Favorable
# 29                    Yes, I use AI tools daily         Favorable
#
#                          AIAcc  \
# 0   Neither trust nor distrust
# 1   Neither trust nor distrust
# 2               Somewhat trust
# 3               Somewhat trust
# 4   Neither trust nor distrust
# 5            Somewhat distrust
# 6               Somewhat trust
# 7               Somewhat trust
# 8   Neither trust nor distrust
# 9              Highly distrust
# 10           Somewhat distrust
# 11  Neither trust nor distrust
# 12           Somewhat distrust
# 13                         NaN
# 14              Somewhat trust
# 15                Highly trust
# 16             Highly distrust
# 17  Neither trust nor distrust
# 18             Highly distrust
# 19  Neither trust nor distrust
# 20             Highly distrust
# 21             Highly distrust
# 22           Somewhat distrust
# 23           Somewhat distrust
# 24             Highly distrust
# 25  Neither trust nor distrust
# 26              Somewhat trust
# 27  Neither trust nor distrust
# 28              Somewhat trust
# 29           Somewhat distrust
#
#                                             AIComplex  \
# 0                       Bad at handling complex tasks
# 1                       Bad at handling complex tasks
# 2       Neither good or bad at handling complex tasks
# 3                       Bad at handling complex tasks
# 4       Good, but not great at handling complex tasks
# 5       Good, but not great at handling complex tasks
# 6       Neither good or bad at handling complex tasks
# 7       Neither good or bad at handling complex tasks
# 8       Neither good or bad at handling complex tasks
# 9                 Very poor at handling complex tasks
# 10                Very poor at handling complex tasks
# 11                      Bad at handling complex tasks
# 12                      Bad at handling complex tasks
# 13                                                NaN
# 14      Good, but not great at handling complex tasks
# 15      Good, but not great at handling complex tasks
# 16  I don't use AI tools for complex tasks / I don...
# 17      Good, but not great at handling complex tasks
# 18                Very poor at handling complex tasks
# 19                Very well at handling complex tasks
# 20  I don't use AI tools for complex tasks / I don...
# 21  I don't use AI tools for complex tasks / I don...
# 22                      Bad at handling complex tasks
# 23                Very poor at handling complex tasks
# 24  I don't use AI tools for complex tasks / I don...
# 25      Good, but not great at handling complex tasks
# 26      Good, but not great at handling complex tasks
# 27                      Bad at handling complex tasks
# 28      Neither good or bad at handling complex tasks
# 29                Very poor at handling complex tasks
#
#                          AIToolCurrently partially AI  \
# 0   Learning about a codebase;Writing code;Search ...
# 1               Learning new concepts or technologies
# 2   Documenting code;Debugging or fixing code;Test...
# 3                                                 NaN
# 4   Learning about a codebase;Writing code;Debuggi...
# 5   Learning about a codebase;Writing code;Documen...
# 6   Learning about a codebase;Writing code;Documen...
# 7                       Writing code;Documenting code
# 8                                                 NaN
# 9                                                 NaN
# 10  Learning about a codebase;Project planning;Wri...
# 11  Learning about a codebase;Writing code;Debuggi...
# 12                                                NaN
# 13                                                NaN
# 14  Learning about a codebase;Project planning;Deb...
# 15                                 Search for answers
# 16                                                NaN
# 17  Writing code;Documenting code;Debugging or fix...
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                       Writing code
# 23  Search for answers;Generating content or synth...
# 24                                                NaN
# 25  Learning about a codebase;Project planning;Wri...
# 26       Writing code;Testing code;Search for answers
# 27                                                NaN
# 28  Testing code;Search for answers;Learning new c...
# 29  Writing code;Learning new concepts or technolo...
#
#              AIToolDon't plan to use AI for this task  \
# 0   Project planning;Deployment and monitoring;Lea...
# 1   Learning about a codebase;Project planning;Com...
# 2                                                 NaN
# 3   Project planning;Documenting code;Testing code...
# 4   Project planning;Documenting code;Testing code...
# 5                                Predictive analytics
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  Debugging or fixing code;Testing code;Deployme...
# 11  Project planning;Documenting code;Testing code...
# 12                                   Project planning
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16  Learning about a codebase;Project planning;Wri...
# 17  Project planning;Testing code;Committing and r...
# 18  Learning about a codebase;Project planning;Doc...
# 19                                                NaN
# 20                                                NaN
# 21  Learning about a codebase;Project planning;Wri...
# 22  Learning about a codebase;Project planning;Doc...
# 23  Learning about a codebase;Project planning;Wri...
# ...
# 11  It takes significant time and effort to learn ...
# 12  I am concerned about the accuracy of the infor...
# 13                                                NaN
# 14                                                NaN
# 15  The cost of using certain AI agent platforms i...
# 16                                                NaN
# 17  I am concerned about the accuracy of the infor...
# 18  My company's IT and/or InfoSec teams have stri...
# 19                                                NaN
# 20  I am concerned about the accuracy of the infor...
# 21                                                NaN
# 22  I am concerned about the accuracy of the infor...
# 23  I am concerned about the accuracy of the infor...
# 24                                                NaN
# 25  I am concerned about the accuracy of the infor...
# 26  Integrating AI agents with my existing tools a...
# 27  I have concerns about the security and privacy...
# 28  I am concerned about the accuracy of the infor...
# 29                                                NaN
#
#                    AIAgentChallengesStrongly disagree  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   My company's IT and/or InfoSec teams have stri...
# 6                                                 NaN
# 7   Integrating AI agents with my existing tools a...
# 8                                                 NaN
# 9   My company's IT and/or InfoSec teams have stri...
# 10  It takes significant time and effort to learn ...
# 11  My company's IT and/or InfoSec teams have stri...
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17  My company's IT and/or InfoSec teams have stri...
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22  My company's IT and/or InfoSec teams have stri...
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29  The cost of using certain AI agent platforms i...
#
#                         AIAgentKnowledge AIAgentKnowWrite  \
# 0                                    NaN              NaN
# 1                                    NaN              NaN
# 2                                  Redis              NaN
# 3                                    NaN              NaN
# 4                                    NaN              NaN
# 5                                    NaN              NaN
# 6                                    NaN              NaN
# 7                                    NaN              NaN
# 8                                    NaN              NaN
# 9                                    NaN              NaN
# 10                                   NaN              NaN
# 11                                   NaN              NaN
# 12                                   NaN              NaN
# 13                                   NaN              NaN
# 14                                   NaN              NaN
# 15  Fireproof;LanceDB;Letta;Neo4j;Qdrant              NaN
# 16                                   NaN              NaN
# 17                                   NaN              NaN
# 18                                   NaN              NaN
# 19                                   NaN              NaN
# 20                                   NaN              NaN
# 21                                   NaN              NaN
# 22                                   NaN              NaN
# 23                                   NaN              NaN
# 24                                   NaN              NaN
# 25                                   NaN              NaN
# 26                                   NaN              NaN
# 27                                   NaN              NaN
# 28                                 Redis           ollama
# 29                                   NaN              NaN
#
#                                  AIAgentOrchestration AIAgentOrchWrite  \
# 0                                           Vertex AI              NaN
# 1                                                 NaN              NaN
# 2                                                 NaN              NaN
# 3                                                 NaN              NaN
# 4                                                 NaN              NaN
# 5                                                 NaN              NaN
# 6                                                 NaN              NaN
# 7                                                 NaN              NaN
# 8                                                 NaN              NaN
# 9                                                 NaN              NaN
# 10                                                NaN        Spring AI
# 11                                                NaN              NaN
# 12                                                NaN              NaN
# 13                                                NaN              NaN
# 14                                                NaN              NaN
# 15  Vertex AI;Agno;AutoGen (Microsoft);CrewAI;IBM ...              NaN
# 16                                                NaN              NaN
# 17                                                NaN              NaN
# 18                                                NaN              NaN
# 19                                                NaN              NaN
# 20                                                NaN              NaN
# 21                                                NaN              NaN
# 22                                                NaN              NaN
# 23                                                NaN              NaN
# 24                                                NaN              NaN
# 25                                                NaN              NaN
# 26                                                NaN              NaN
# 27                                                NaN              NaN
# 28                                             Ollama              NaN
# 29                                                NaN              NaN
#
#                             AIAgentObserveSecure AIAgentObsWrite  \
# 0                                            NaN             NaN
# 1                                            NaN             NaN
# 2                                            NaN             NaN
# 3                                            NaN             NaN
# 4                                            NaN             NaN
# 5                                            NaN             NaN
# 6                                         Sentry             NaN
# 7                                            NaN             NaN
# 8                                            NaN             NaN
# 9                                            NaN             NaN
# 10                                           NaN             NaN
# 11                                           NaN             NaN
# 12                                           NaN             NaN
# 13                                           NaN             NaN
# 14                                           NaN             NaN
# 15  Galileo;Honeycomb;Metero;New Relic;opik;Snyk             NaN
# 16                                           NaN             NaN
# 17                                           NaN             NaN
# 18                                           NaN             NaN
# 19                                           NaN             NaN
# 20                                           NaN             NaN
# 21                                           NaN             NaN
# 22                                           NaN             NaN
# 23                                           NaN             NaN
# 24                                           NaN             NaN
# 25                                           NaN             NaN
# 26                                           NaN             NaN
# 27                                           NaN             NaN
# 28                                     Honeycomb             NaN
# 29                                           NaN             NaN
#
#                                       AIAgentExternal AIAgentExtWrite  \
# 0                                             ChatGPT             NaN
# 1                                                 NaN             NaN
# 2    ChatGPT;Claude Code;GitHub Copilot;Google Gemini             NaN
# 3                                 ChatGPT;Claude Code             NaN
# 4                                                 NaN             NaN
# 5                                      GitHub Copilot             NaN
# 6                   ChatGPT;Claude Code;Google Gemini             NaN
# 7                                                 NaN             NaN
# 8                                                 NaN             NaN
# 9                                                 NaN             NaN
# 10  ChatGPT;Claude Code;GitHub Copilot;Microsoft C...             NaN
# 11                                                NaN             NaN
# 12                                                NaN             NaN
# 13                                                NaN             NaN
# 14                                                NaN             NaN
# 15  ChatGPT;AgentGPT;Auto-GPT;Devin AI;Glean (Ente...             NaN
# 16                                                NaN             NaN
# 17                                                NaN             NaN
# 18                                                NaN             NaN
# 19                                                NaN             NaN
# 20                                                NaN             NaN
# 21                                                NaN             NaN
# 22                                                NaN             NaN
# 23                                                NaN             NaN
# 24                                                NaN             NaN
# 25                      ChatGPT;GitHub Copilot;Replit             NaN
# 26                                                NaN             NaN
# 27                                                NaN             NaN
# 28               ChatGPT;GitHub Copilot;Google Gemini          Cursor
# 29                                                NaN             NaN
#
#                                               AIHuman  \
# 0                     When I don’t trust AI’s answers
# 1   When I don’t trust AI’s answers;When I want to...
# 2   When I don’t trust AI’s answers;When I want to...
# 3   When I don’t trust AI’s answers;When I want to...
# 4                     When I don’t trust AI’s answers
# 5   When I have ethical or security concerns about...
# 6   When I don’t trust AI’s answers;When I need he...
# 7   When I want to learn best practices;When I wan...
# 8                                                 NaN
# 9   When I’m stuck and can’t explain the problem;W...
# 10  When I don’t trust AI’s answers;When I have et...
# 11  When I don’t trust AI’s answers;When I need qu...
# 12  When I want to fully understand something;When...
# 13                                                NaN
# 14   I don’t think I’ll need help from people anymore
# 15  When I don’t trust AI’s answers;When I have et...
# 16                            Other (please specify):
# 17  When I want to learn best practices;When I hav...
# 18  When I don’t trust AI’s answers;When I want to...
# 19   I don’t think I’ll need help from people anymore
# 20                                                NaN
# 21  When I don’t trust AI’s answers;When I want to...
# 22  When I don’t trust AI’s answers;When I want to...
# 23  When I don’t trust AI’s answers;When I want to...
# 24  When I don’t trust AI’s answers;When I’m stuck...
# 25  When I don’t trust AI’s answers;When I want to...
# 26  When I don’t trust AI’s answers;When I want to...
# 27  When I don’t trust AI’s answers;When I want to...
# 28  When I don’t trust AI’s answers;When I want to...
# 29  When I don’t trust AI’s answers;When I want to...
#
#                                                AIOpen ConvertedCompYearly  \
# 0               Troubleshooting, profiling, debugging             61256.0
# 1                           All skills. AI is a flop.            104413.0
# 2   Understand how things actually work, problem s...             53061.0
# 3                                                 NaN             36197.0
# 4   critical thinking, the skill to define the tas...             60000.0
# 5        designing the architecture in the new domain            120000.0
# 6                                                 NaN              6240.0
# 7                           Innovation, system design             72000.0
# 8                                                 NaN             70000.0
# 9                                                 NaN              5400.0
# 10  Code writing. I know this sounds weird but you...             65691.0
# 11                                                NaN             14400.0
# 12                                                NaN              1099.0
# 13                                                NaN                 NaN
# 14                                 senior development                 NaN
# 15                                                  5                 NaN
# 16  All the ones that INTELLIGENT programmers curr...             16252.0
# 17                                                NaN                 NaN
# 18      AI will not become more capable in 3-5 years.                 NaN
# 19                                           Research                 NaN
# 20                                                NaN                 NaN
# 21                            interacting with people                 NaN
# 22  Technical knowledge. As AI slides into the for...             87500.0
# 23                     Problem solving, communication                 NaN
# 24  Real coding skills, assembler, mainframe, COBO...                 NaN
# 25  Choosing the best solutions. Converting user r...            108913.0
# 26  The ability to tackle more open ended problems...            162421.0
# 27                                                NaN            209643.0
# 28       System Design, Maintainability, Common Sense             78000.0
# 29  Being able to make sure the AI code is correct...            205000.0
#
#    JobSat
# 0    10.0
# 1     9.0
# 2     8.0
# 3     6.0
# 4     7.0
# 5     7.0
# 6     6.0
# 7     6.0
# 8     8.0
# 9     4.0
# 10   10.0
# 11    8.0
# 12    7.0
# 13    6.0
# 14    9.0
# 15    7.0
# 16    NaN
# 17    6.0
# 18    5.0
# 19    NaN
# 20    NaN
# 21    NaN
# 22    9.0
# 23    8.0
# 24    9.0
# 25    8.0
# 26    8.0
# 27    9.0
# 28   10.0
# 29    8.0
#
# [30 rows x 172 columns]

# %%
df.tail(10)
# Out:
#        ResponseId                                         MainBranch  \
# 49181       49182                     I am a developer by profession
# 49182       49183                     I am a developer by profession
# 49183       49184                     I am a developer by profession
# 49184       49185  I am not primarily a developer, but I write co...
# 49185       49186                     I am a developer by profession
# 49186       49187                        I code primarily as a hobby
# 49187       49188                     I am a developer by profession
# 49188       49189                     I am a developer by profession
# 49189       49190                     I am a developer by profession
# 49190       49191  I am not primarily a developer, but I write co...
#
#                    Age                                            EdLevel  \
# 49181  25-34 years old       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 49182  35-44 years old                                                NaN
# 49183  25-34 years old    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 49184  45-54 years old     Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 49185  25-34 years old       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 49186  18-24 years old       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 49187  45-54 years old  Some college/university study without earning ...
# 49188  35-44 years old    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 49189  25-34 years old     Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 49190  18-24 years old  Some college/university study without earning ...
#
#                                               Employment  \
# 49181                                            Student
# 49182                                                NaN
# 49183                                           Employed
# 49184                                           Employed
# 49185                                           Employed
# 49186                                           Employed
# 49187                                           Employed
# 49188                                           Employed
# 49189  Independent contractor, freelancer, or self-em...
# 49190                                            Student
#
#                                           EmploymentAddl  WorkExp  \
# 49181                                                NaN      NaN
# 49182                                                NaN      NaN
# 49183                                  None of the above      2.0
# 49184  Caring for dependents (children, elderly, etc....     30.0
# 49185                                                NaN      NaN
# 49186                                                NaN      NaN
# 49187    Caring for dependents (children, elderly, etc.)     25.0
# 49188                                  None of the above     17.0
# 49189                                  None of the above      2.0
# 49190                       Attending school (full-time)      NaN
#
#                                          LearnCodeChoose  \
# 49181                                                NaN
# 49182                                                NaN
# 49183     Yes, I am new to coding or currently a student
# 49184  Yes, I am not new to coding but am learning ne...
# 49185                                                NaN
# 49186                                                NaN
# 49187  Yes, I am not new to coding but am learning ne...
# 49188  Yes, I am not new to coding but am learning ne...
# 49189  Yes, I am not new to coding but am learning ne...
# 49190  Yes, I am not new to coding but am learning ne...
#
#                                                LearnCode  \
# 49181                                                NaN
# 49182                                                NaN
# 49183  Books / Physical media;Videos (not associated ...
# 49184  Online Courses or Certification (includes all ...
# 49185                                                NaN
# 49186                                                NaN
# 49187  Online Courses or Certification (includes all ...
# 49188  Online Courses or Certification (includes all ...
# 49189  Videos (not associated with specific online co...
# 49190  Online Courses or Certification (includes all ...
#
#                                              LearnCodeAI  \
# 49181                                                NaN
# 49182                                                NaN
# 49183  Yes, I learned how to use AI-enabled tools for...
# 49184  Yes, I learned how to use AI-enabled tools req...
# 49185                                                NaN
# 49186                                                NaN
# 49187  Yes, I learned how to use AI-enabled tools req...
# 49188  Yes, I learned how to use AI-enabled tools for...
# 49189  Yes, I learned how to use AI-enabled tools for...
# 49190  Yes, I learned how to use AI-enabled tools for...
#
#                                               AILearnHow  YearsCode  \
# 49181                                                NaN        NaN
# 49182                                                NaN        NaN
# 49183  Videos (not associated with specific online co...        2.0
# 49184                                                NaN        NaN
# 49185                                                NaN        NaN
# 49186                                                NaN        NaN
# 49187                                                NaN        NaN
# 49188  AI CodeGen tools or AI-enabled apps;Videos (no...       31.0
# 49189                                                NaN        NaN
# 49190                AI CodeGen tools or AI-enabled apps        6.0
#
#                                 DevType                   OrgSize  \
# 49181                               NaN                       NaN
# 49182                               NaN                       NaN
# 49183          Data or business analyst              I don’t know
# 49184                               NaN                       NaN
# 49185                               NaN                       NaN
# 49186                               NaN                       NaN
# 49187                               NaN                       NaN
# 49188  Architect, software or solutions  10,000 or more employees
# 49189                               NaN                       NaN
# 49190                           Student                       NaN
#
#                        ICorPM  \
# 49181                     NaN
# 49182                     NaN
# 49183  Individual contributor
# 49184                     NaN
# 49185                     NaN
# 49186                     NaN
# 49187                     NaN
# 49188          People manager
# 49189                     NaN
# 49190                     NaN
#
#                                               RemoteWork  \
# 49181                                                NaN
# 49182                                                NaN
# 49183  Hybrid (some in-person, leans heavy to flexibi...
# 49184                                                NaN
# 49185                                                NaN
# 49186                                                NaN
# 49187                                                NaN
# 49188  Hybrid (some in-person, leans heavy to flexibi...
# 49189                                                NaN
# 49190                                                NaN
#
#                                        PurchaseInfluence  TechEndorseIntro  \
# 49181                                                NaN               NaN
# 49182                                                NaN               NaN
# 49183                                                 No              Work
# 49184                                                NaN               NaN
# 49185                                                NaN               NaN
# 49186                                                NaN               NaN
# 49187                                                NaN               NaN
# 49188  Yes, I endorsed a tool that was open-source an...  Personal Project
# 49189                                                NaN               NaN
# 49190                                                NaN               NaN
#
#        TechEndorse_1  TechEndorse_2  TechEndorse_3  TechEndorse_4  \
# 49181            NaN            NaN            NaN            NaN
# 49182            NaN            NaN            NaN            NaN
# 49183            9.0            6.0            7.0            5.0
# 49184            NaN            NaN            NaN            NaN
# 49185            NaN            NaN            NaN            NaN
# 49186            NaN            NaN            NaN            NaN
# 49187            NaN            NaN            NaN            NaN
# 49188            9.0            2.0            1.0            5.0
# 49189            NaN            NaN            NaN            NaN
# 49190            NaN            NaN            NaN            NaN
#
#        TechEndorse_5  TechEndorse_6  TechEndorse_7  TechEndorse_8  \
# 49181            NaN            NaN            NaN            NaN
# 49182            NaN            NaN            NaN            NaN
# 49183            1.0            2.0           10.0            4.0
# 49184            NaN            NaN            NaN            NaN
# 49185            NaN            NaN            NaN            NaN
# 49186            NaN            NaN            NaN            NaN
# 49187            NaN            NaN            NaN            NaN
# 49188            3.0            7.0            8.0            4.0
# 49189            NaN            NaN            NaN            NaN
# 49190            NaN            NaN            NaN            NaN
#
#        TechEndorse_9  TechEndorse_13 TechEndorse_13_TEXT  TechOppose_1  \
# 49181            NaN             NaN                 NaN           NaN
# 49182            NaN             NaN                 NaN           NaN
# 49183            3.0             8.0                 NaN           8.0
# 49184            NaN             NaN                 NaN           NaN
# 49185            NaN             NaN                 NaN           NaN
# 49186            NaN             NaN                 NaN           NaN
# 49187            NaN             NaN                 NaN           NaN
# 49188            6.0            10.0                 NaN           9.0
# 49189            NaN             NaN                 NaN           NaN
# 49190            NaN             NaN                 NaN           NaN
#
#        TechOppose_2  TechOppose_3  TechOppose_5  TechOppose_7  TechOppose_9  \
# 49181           NaN           NaN           NaN           NaN           NaN
# 49182           NaN           NaN           NaN           NaN           NaN
# 49183           5.0           9.0           3.0           2.0           4.0
# 49184           NaN           NaN           NaN           NaN           NaN
# 49185           NaN           NaN           NaN           NaN           NaN
# 49186           NaN           NaN           NaN           NaN           NaN
# 49187           NaN           NaN           NaN           NaN           NaN
# 49188           6.0           2.0           7.0           5.0           4.0
# 49189           NaN           NaN           NaN           NaN           NaN
# 49190           NaN           NaN           NaN           NaN           NaN
#
#        TechOppose_11  TechOppose_13  TechOppose_16  TechOppose_15  \
# 49181            NaN            NaN            NaN            NaN
# 49182            NaN            NaN            NaN            NaN
# 49183            7.0            6.0            1.0           10.0
# 49184            NaN            NaN            NaN            NaN
# 49185            NaN            NaN            NaN            NaN
# 49186            NaN            NaN            NaN            NaN
# 49187            NaN            NaN            NaN            NaN
# 49188            1.0            3.0            8.0           10.0
# 49189            NaN            NaN            NaN            NaN
# 49190            NaN            NaN            NaN            NaN
#
#       TechOppose_15_TEXT                    Industry  JobSatPoints_1  ...  \
# 49181                NaN                         NaN             NaN  ...
# 49182                NaN                         NaN             NaN  ...
# 49183                NaN                   Insurance             NaN  ...
# 49184                NaN                         NaN             NaN  ...
# 49185                NaN                         NaN             NaN  ...
# 49186                NaN                         NaN             NaN  ...
# 49187                NaN                         NaN             NaN  ...
# 49188                NaN  Banking/Financial Services             3.0  ...
# 49189                NaN                         NaN             NaN  ...
# 49190                NaN                         NaN             NaN  ...
#
#        SO_Actions_10  SO_Actions_15  SO_Actions_15_TEXT  SOComm  SOFriction  \
# 49181            NaN            NaN                 NaN     NaN         NaN
# 49182            NaN            NaN                 NaN     NaN         NaN
# 49183            NaN            NaN                 NaN     NaN         NaN
# 49184            NaN            NaN                 NaN     NaN         NaN
# 49185            NaN            NaN                 NaN     NaN         NaN
# 49186            NaN            NaN                 NaN     NaN         NaN
# 49187            NaN            NaN                 NaN     NaN         NaN
# 49188            NaN            NaN                 NaN     NaN         NaN
# 49189            NaN            NaN                 NaN     NaN         NaN
# 49190            NaN            NaN                 NaN     NaN         NaN
#
#                                           AISelect     AISent  \
# 49181                                          NaN        NaN
# 49182                                          NaN        NaN
# 49183                                          NaN        NaN
# 49184                                          NaN        NaN
# 49185                                          NaN        NaN
# 49186                                          NaN        NaN
# 49187                                          NaN        NaN
# 49188  Yes, I use AI tools monthly or infrequently  Favorable
# 49189                                          NaN        NaN
# 49190                                          NaN        NaN
#
#                             AIAcc  \
# 49181                         NaN
# 49182                         NaN
# 49183                         NaN
# 49184                         NaN
# 49185                         NaN
# 49186                         NaN
# 49187                         NaN
# 49188  Neither trust nor distrust
# 49189                         NaN
# 49190                         NaN
#
#                                            AIComplex  \
# 49181                                            NaN
# 49182                                            NaN
# 49183                                            NaN
# 49184                                            NaN
# 49185                                            NaN
# 49186                                            NaN
# 49187                                            NaN
# 49188  Good, but not great at handling complex tasks
# 49189                                            NaN
# 49190                                            NaN
#
#                             AIToolCurrently partially AI  \
# 49181                                                NaN
# 49182                                                NaN
# 49183                                                NaN
# 49184                                                NaN
# 49185                                                NaN
# 49186                                                NaN
# 49187                                                NaN
# 49188  Learning about a codebase;Writing code;Documen...
# 49189                                                NaN
# 49190                                                NaN
#
#        AIToolDon't plan to use AI for this task  \
# 49181                                       NaN
# 49182                                       NaN
# 49183                                       NaN
# 49184                                       NaN
# 49185                                       NaN
# 49186                                       NaN
# 49187                                       NaN
# 49188                  Debugging or fixing code
# 49189                                       NaN
# 49190                                       NaN
#
#                           AIToolPlan to partially use AI  \
# 49181                                                NaN
# 49182                                                NaN
# 49183                                                NaN
# 49184                                                NaN
# 49185                                                NaN
# 49186                                                NaN
# 49187                                                NaN
# 49188  Project planning;Deployment and monitoring;Pre...
# 49189                                                NaN
# 49190                                                NaN
#
#        AIToolPlan to mostly use AI  AIToolCurrently mostly AI  \
# 49181                          NaN                        NaN
# 49182                          NaN                        NaN
# 49183                          NaN                        NaN
# 49184                          NaN                        NaN
# 49185                          NaN                        NaN
# 49186                          NaN                        NaN
# 49187                          NaN                        NaN
# 49188                          NaN         Search for answers
# 49189                          NaN                        NaN
# 49190                          NaN                        NaN
#
#                                            AIFrustration        AIExplain  \
# 49181                                                NaN              NaN
# 49182                                                NaN              NaN
# 49183                                                NaN              NaN
# 49184                                                NaN              NaN
# 49185                                                NaN              NaN
# 49186                                                NaN              NaN
# 49187                                                NaN              NaN
# 49188  AI solutions that are almost right, but not qu...  Yes, partially.
# 49189                                                NaN              NaN
# 49190                                                NaN              NaN
#
#                                                 AIAgents  \
# 49181                                                NaN
# 49182                                                NaN
# 49183                                                NaN
# 49184                                                NaN
# 49185                                                NaN
# 49186                                                NaN
# 49187                                                NaN
# 49188  No, I use AI exclusively in copilot/autocomple...
# 49189                                                NaN
# 49190                                                NaN
#
#                  AIAgentChange  AIAgent_Uses AgentUsesGeneral  \
# 49181                      NaN           NaN              NaN
# 49182                      NaN           NaN              NaN
# 49183                      NaN           NaN              NaN
# 49184                      NaN           NaN              NaN
# 49185                      NaN           NaN              NaN
# 49186                      NaN           NaN              NaN
# 49187                      NaN           NaN              NaN
# 49188  Not at all or minimally           NaN              NaN
# 49189                      NaN           NaN              NaN
# 49190                      NaN           NaN              NaN
#
#       AIAgentImpactSomewhat agree  AIAgentImpactNeutral  \
# 49181                         NaN                   NaN
# 49182                         NaN                   NaN
# 49183                         NaN                   NaN
# 49184                         NaN                   NaN
# 49185                         NaN                   NaN
# 49186                         NaN                   NaN
# 49187                         NaN                   NaN
# 49188                         NaN                   NaN
# 49189                         NaN                   NaN
# 49190                         NaN                   NaN
#
#       AIAgentImpactSomewhat disagree AIAgentImpactStrongly agree  \
# 49181                            NaN                         NaN
# 49182                            NaN                         NaN
# 49183                            NaN                         NaN
# 49184                            NaN                         NaN
# 49185                            NaN                         NaN
# 49186                            NaN                         NaN
# 49187                            NaN                         NaN
# 49188                            NaN                         NaN
# 49189                            NaN                         NaN
# 49190                            NaN                         NaN
#
#                   AIAgentImpactStrongly disagree AIAgentChallengesNeutral  \
# 49181                                        NaN                      NaN
# 49182                                        NaN                      NaN
# 49183                                        NaN                      NaN
# 49184                                        NaN                      NaN
# 49185                                        NaN                      NaN
# 49186                                        NaN                      NaN
# 49187                                        NaN                      NaN
# 49188  AI agents have increased my productivity.                      NaN
# 49189                                        NaN                      NaN
# 49190                                        NaN                      NaN
#
#       AIAgentChallengesSomewhat disagree AIAgentChallengesStrongly agree  \
# 49181                                NaN                             NaN
# 49182                                NaN                             NaN
# 49183                                NaN                             NaN
# 49184                                NaN                             NaN
# 49185                                NaN                             NaN
# 49186                                NaN                             NaN
# 49187                                NaN                             NaN
# 49188                                NaN                             NaN
# 49189                                NaN                             NaN
# 49190                                NaN                             NaN
#
#       AIAgentChallengesSomewhat agree AIAgentChallengesStrongly disagree  \
# 49181                             NaN                                NaN
# 49182                             NaN                                NaN
# 49183                             NaN                                NaN
# 49184                             NaN                                NaN
# 49185                             NaN                                NaN
# 49186                             NaN                                NaN
# 49187                             NaN                                NaN
# 49188                             NaN                                NaN
# 49189                             NaN                                NaN
# 49190                             NaN                                NaN
#
#       AIAgentKnowledge AIAgentKnowWrite AIAgentOrchestration AIAgentOrchWrite  \
# 49181              NaN              NaN                  NaN              NaN
# 49182              NaN              NaN                  NaN              NaN
# 49183              NaN              NaN                  NaN              NaN
# 49184              NaN              NaN                  NaN              NaN
# 49185              NaN              NaN                  NaN              NaN
# 49186              NaN              NaN                  NaN              NaN
# 49187              NaN              NaN                  NaN              NaN
# 49188              NaN              NaN                  NaN              NaN
# 49189              NaN              NaN                  NaN              NaN
# 49190              NaN              NaN                  NaN              NaN
#
#       AIAgentObserveSecure AIAgentObsWrite AIAgentExternal AIAgentExtWrite  \
# 49181                  NaN             NaN             NaN             NaN
# 49182                  NaN             NaN             NaN             NaN
# 49183                  NaN             NaN             NaN             NaN
# 49184                  NaN             NaN             NaN             NaN
# 49185                  NaN             NaN             NaN             NaN
# 49186                  NaN             NaN             NaN             NaN
# 49187                  NaN             NaN             NaN             NaN
# 49188                  NaN             NaN             NaN             NaN
# 49189                  NaN             NaN             NaN             NaN
# 49190                  NaN             NaN             NaN             NaN
#
#       AIHuman AIOpen ConvertedCompYearly JobSat
# 49181     NaN    NaN                 NaN    NaN
# 49182     NaN    NaN                 NaN    NaN
# 49183     NaN    NaN                 NaN    NaN
# 49184     NaN    NaN                 NaN    NaN
# 49185     NaN    NaN                 NaN    NaN
# 49186     NaN    NaN                 NaN    NaN
# 49187     NaN    NaN                 NaN    NaN
# 49188     NaN    NaN                 NaN    9.0
# 49189     NaN    NaN                 NaN    NaN
# 49190     NaN    NaN                 NaN    NaN
#
# [10 rows x 172 columns]

# %%
df.shape
# Out:
# (49191, 172)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49191 entries, 0 to 49190
# Columns: 172 entries, ResponseId to JobSat
# dtypes: float64(52), int64(1), object(119)
# memory usage: 64.6+ MB

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 200)

# %%
schema_df = pd.read_csv('data/survey_results_schema.csv')

# %%
schema_df
# Out:
#         qid                 qname  \
# 0     QID18         TechEndorse_1
# 1     QID18         TechEndorse_2
# 2     QID18         TechEndorse_3
# 3     QID18         TechEndorse_4
# 4     QID18         TechEndorse_5
# 5     QID18         TechEndorse_6
# 6     QID18         TechEndorse_7
# 7     QID18         TechEndorse_8
# 8     QID18         TechEndorse_9
# 9     QID18        TechEndorse_13
# 10    QID18   TechEndorse_13_TEXT
# 11    QID19          TechOppose_1
# 12    QID19          TechOppose_2
# 13    QID19          TechOppose_3
# 14    QID19          TechOppose_5
# 15    QID19          TechOppose_7
# 16    QID19          TechOppose_9
# 17    QID19         TechOppose_11
# 18    QID19         TechOppose_13
# 19    QID19         TechOppose_16
# 20    QID19         TechOppose_15
# 21    QID19    TechOppose_15_TEXT
# 22    QID27        JobSatPoints_1
# 23    QID27        JobSatPoints_2
# 24    QID27       JobSatPoints_16
# 25    QID27        JobSatPoints_3
# 26    QID27        JobSatPoints_4
# 27    QID27        JobSatPoints_5
# 28    QID27        JobSatPoints_6
# 29    QID27        JobSatPoints_7
# 30    QID27        JobSatPoints_8
# 31    QID27        JobSatPoints_9
# 32    QID27       JobSatPoints_10
# 33    QID27       JobSatPoints_11
# 34    QID27       JobSatPoints_13
# 35    QID27       JobSatPoints_14
# 36    QID27       JobSatPoints_15
# 37    QID27  JobSatPoints_15_TEXT
# 38    QID76          SO_Actions_1
# 39    QID76         SO_Actions_16
# 40    QID76          SO_Actions_3
# 41    QID76          SO_Actions_4
# 42    QID76          SO_Actions_5
# 43    QID76          SO_Actions_6
# 44    QID76          SO_Actions_9
# 45    QID76          SO_Actions_7
# 46    QID76         SO_Actions_10
# 47    QID76         SO_Actions_15
# 48    QID76    SO_Actions_15_TEXT
# 49     QID3            MainBranch
# 50     QID4                   Age
# 51     QID9               EdLevel
# 52     QID7            Employment
# 53     QID8        EmploymentAddl
# 54    QID14               WorkExp
# 55    QID10       LearnCodeChoose
# 56    QID11             LearnCode
# 57    QID12           LearnCodeAI
# 58    QID32            AILearnHow
# 59    QID13             YearsCode
# 60    QID15               DevType
# 61    QID16               OrgSize
# 62    QID23                ICorPM
# 63    QID24            RemoteWork
# 64    QID17     PurchaseInfluence
# 65    QID33      TechEndorseIntro
# 66    QID25              Industry
# 67    QID26                JobSat
# 68    QID28              AIThreat
# 69    QID29               NewRole
# 70    QID30         ToolCountWork
# 71    QID31     ToolCountPersonal
# 72    QID20               Country
# 73    QID21              Currency
# 74    QID22             CompTotal
# 75    QID44        LanguageChoice
# 76    QID34              Language
# 77    QID51    LanguagesHaveEntry
# 78    QID52    LanguagesWantEntry
# 79    QID45        DatabaseChoice
# 80    QID35              Database
# 81    QID54     DatabaseHaveEntry
# 82    QID55     DatabaseWantEntry
# 83    QID46        PlatformChoice
# 84    QID36              Platform
# 85    QID56     PlatformHaveEntry
# 86    QID57     PlatformWantEntry
# 87    QID47        WebframeChoice
# 88    QID37              Webframe
# 89    QID58     WebframeHaveEntry
# 90    QID59     WebframeWantEntry
# 91    QID48         DevEnvsChoice
# 92    QID38               DevEnvs
# 93    QID60       DevEnvHaveEntry
# 94    QID61       DevEnvWantEntry
# 95    QID39                SOTags
# 96    QID62       SOTagsHaveEntry
# 97    QID63      SOTagsWant Entry
# 98    QID40                 OpSys
# 99    QID41      OfficeStackAsync
# 100   QID64  OfficeStackHaveEntry
# 101   QID65  OfficeStackWantEntry
# 102   QID42          CommPlatform
# 103   QID66  CommPlatformHaveEntr
# 104   QID67  CommPlatformWantEntr
# 105   QID50        AIModelsChoice
# 106   QID43              AIModels
# 107   QID68     AIModelsHaveEntry
# 108   QID69     AIModelsWantEntry
# 109   QID72             SOAccount
# 110   QID70           SOVisitFreq
# 111   QID71            SODuration
# 112   QID73            SOPartFreq
# 113   QID75        SO_Dev_Content
# 114   QID77                SOComm
# 115   QID97            SOFriction
# 116   QID78              AISelect
# 117   QID79                AISent
# 118   QID80                 AIAcc
# 119   QID81             AIComplex
# 120   QID82                AITool
# 121   QID99         AIFrustration
# 122   QID84             AIExplain
# 123   QID85              AIAgents
# 124   QID83         AIAgentChange
# 125   QID86          AIAgent_Uses
# 126  QID106      AgentUsesGeneral
# 127   QID87         AIAgentImpact
# 128   QID88     AIAgentChallenges
# 129   QID89      AIAgentKnowledge
# 130  QID107      AIAgentKnowWrite
# 131   QID90  AIAgentOrchestration
# 132  QID102      AIAgentOrchWrite
# 133   QID91  AIAgentObserveSecure
# 134  QID103       AIAgentObsWrite
# 135   QID92       AIAgentExternal
# 136  QID104       AIAgentExtWrite
# 137  QID100               AIHuman
# 138   QID93                AIOpen
#
#                                               question    type  \
# 0    What attracts you to a technology or causes yo...      RO
# 1    What attracts you to a technology or causes yo...      RO
# 2    What attracts you to a technology or causes yo...      RO
# 3    What attracts you to a technology or causes yo...      RO
# 4    What attracts you to a technology or causes yo...      RO
# 5    What attracts you to a technology or causes yo...      RO
# 6    What attracts you to a technology or causes yo...      RO
# 7    What attracts you to a technology or causes yo...      RO
# 8    What attracts you to a technology or causes yo...      RO
# 9    What attracts you to a technology or causes yo...      RO
# 10   What attracts you to a technology or causes yo...      RO
# 11   What would turn you off or cause you to reject...      RO
# 12   What would turn you off or cause you to reject...      RO
# 13   What would turn you off or cause you to reject...      RO
# 14   What would turn you off or cause you to reject...      RO
# 15   What would turn you off or cause you to reject...      RO
# 16   What would turn you off or cause you to reject...      RO
# 17   What would turn you off or cause you to reject...      RO
# 18   What would turn you off or cause you to reject...      RO
# 19   What would turn you off or cause you to reject...      RO
# 20   What would turn you off or cause you to reject...      RO
# 21   What would turn you off or cause you to reject...      RO
# 22   Rank the following attributes of your current ...      RO
# 23   Rank the following attributes of your current ...      RO
# 24   Rank the following attributes of your current ...      RO
# 25   Rank the following attributes of your current ...      RO
# 26   Rank the following attributes of your current ...      RO
# 27   Rank the following attributes of your current ...      RO
# 28   Rank the following attributes of your current ...      RO
# 29   Rank the following attributes of your current ...      RO
# 30   Rank the following attributes of your current ...      RO
# 31   Rank the following attributes of your current ...      RO
# 32   Rank the following attributes of your current ...      RO
# 33   Rank the following attributes of your current ...      RO
# 34   Rank the following attributes of your current ...      RO
# 35   Rank the following attributes of your current ...      RO
# 36   Rank the following attributes of your current ...      RO
# 37   Rank the following attributes of your current ...      RO
# 38   When visiting Stack Overflow, which following ...      RO
# 39   When visiting Stack Overflow, which following ...      RO
# 40   When visiting Stack Overflow, which following ...      RO
# 41   When visiting Stack Overflow, which following ...      RO
# 42   When visiting Stack Overflow, which following ...      RO
# 43   When visiting Stack Overflow, which following ...      RO
# 44   When visiting Stack Overflow, which following ...      RO
# 45   When visiting Stack Overflow, which following ...      RO
# 46   When visiting Stack Overflow, which following ...      RO
# 47   When visiting Stack Overflow, which following ...      RO
# 48   When visiting Stack Overflow, which following ...      RO
# 49   Are you someone who writes code? Please select...      MC
# 50                                   What is your age?      MC
# 51   Which of the following best describes the high...      MC
# 52   Which of the following best describes your cur...      MC
# 53   Which of the following <strong>additional</str...      MC
# 54   How many years of professional work experience...      TE
# 55   Did you begin learning to code or learn a new ...      MC
# 56   How did you learn to code in the past year? Se...      MC
# 57   Did you spend time in the last year learning A...      MC
# 58   How did you learn to code for AI in the past y...      MC
# 59   Including any education, how many years have y...      TE
# 60   Which of the following describes your current ...      MC
# 61   Approximately how many people are employed by ...      MC
# 62   Are you an individual contributor or people ma...      MC
# 63   Which best describes your current work situation?      MC
# 64   Have you <strong>influenced or endorsed</stron...      MC
# 65   When you&rsquo;re in a position to <strong>inf...      MC
# 66                   What industry do you work for in?      MC
# 67   How satisfied are you in your current professi...      MC
# 68   Do you believe AI is a threat to your current ...      MC
# 69   Have you considered a career change or transit...      MC
# 70   For your <b>primary work role</b> (student, de...      TE
# 71   <b></b>For your <b>side projects or other pers...      TE
# 72                                  Where do you live?      MC
# 73   Which currency do you use day-to-day? If your ...      MC
# 74   What is your current total <b>annual</b> compe...      TE
# 75   Did you work with programming, scripting and m...      MC
# 76   Which <b>programming, scripting, and markup la...  Matrix
# 77   Was the programming language you use not liste...      TE
# 78   Was the programming language you want to use n...      TE
# 79   Did you work with database environments in the...      MC
# 80   Which <b>database environments </b>have you do...  Matrix
# 81   Was the database environment you use not liste...      TE
# 82   Was the database environment you want to use n...      TE
# 83   Did you work with cloud platforms, containeriz...      MC
# 84   Which <b>cloud platforms, containerization/orc...  Matrix
# 85   Was the cloud platforms, containerization/orch...      TE
# 86   Was the cloud platforms, containerization/orch...      TE
# 87   Did you work with web frameworks and web techn...      MC
# 88   Which <b>web frameworks and web technologies</...  Matrix
# 89   Were the web frameworks and web technologies y...      TE
# 90   Were the web frameworks and web technologies y...      TE
# 91   Did you work with development environments or ...      MC
# 92   Which <strong>development environments and AI-...  Matrix
# 93   Was the developer environment or AI-enabled co...      TE
# 94   Was the developer environment or AI-enabled co...      TE
# 95   Which rising technology of the added as <b>new...  Matrix
# 96   Was the new tag on Stack Overflow (i.e. added ...      TE
# 97   Was the new tag on Stack Overflow (i.e. added ...      TE
# 98   What is the primary <b>operating system</b> in...  Matrix
# 99   Which <b>collaborative work management and/or ...  Matrix
# 100  Was the collaborative work management and/or c...      TE
# 101  Was the collaborative work management and/or c...      TE
# 102  Which <b>community platforms</b> have you util...  Matrix
# 103  Was the community platform you use not listed ...      TE
# 104  Was the community platform you want to use not...      TE
# 105  Did you utilize or integrate specific Large La...      MC
# 106  Which <b>LLM models for AI tools</b> have you ...  Matrix
# 107  Was the LLM model for AI tools you use not lis...      TE
# 108  Was the LLM model for AI tools you want to use...      TE
# 109              Do you have a Stack Overflow account?      MC
# 110  How frequently would you say you visit Stack O...      MC
# 111             How long have you used Stack Overflow?      MC
# 112  How frequently would you say you participate i...      MC
# 113  Whether it be to solve a problem, for career g...      MC
# 114  Do you consider yourself a member of the Stack...      MC
# 115  When you visit Stack Overflow, how often is it...      MC
# 116  Do you currently use AI tools in your developm...      MC
# 117  How favorable is your stance on using AI tools...      MC
# 118  How much do you trust the accuracy of the outp...      MC
# 119  How well do the AI tools you use in your devel...      MC
# 120  Which parts of your development workflow are y...  Matrix
# 121  When using AI tools, which of the following pr...      MC
# 122  In your own words, is &quot;vibe coding&quot; ...      TE
# 123  Are you using AI agents in your work (developm...      MC
# 124  Have AI tools or AI agents changed how you com...      MC
# 125  What industry purposes or specific tasks are y...      MC
# 126                                                         MC
# 127  To what extent do you agree with the following...  Matrix
# 128  To what extent do you agree with the following...  Matrix
# 129  You indicated you use or develop AI agents as ...      MC
# 130  Was the tool or tools for AI agent orchestrati...      TE
# 131  You indicated you use or develop AI agents as ...      MC
# 132  Was the tool or tools for AI agent orchestrati...      TE
# 133  You indicated you use or develop AI agents as ...      MC
# 134  Was the tool or tools for AI agent observabili...      TE
# 135  You indicated you use or develop AI agents as ...      MC
# 136  Was the out-of-the-box agents, copilots or ass...      TE
# 137  In the future, if AI can do most coding tasks,...      MC
# 138  Looking ahead 3–5 years, what skills do you be...      TE
#
#                                                    sub  sq_id
# 0              AI integration or AI Agent capabilities    1.0
# 1                                      Easy-to-use API    2.0
# 2                              Robust and complete API    3.0
# 3                 Customizable and manageable codebase    4.0
# 4                               Reputation for quality    5.0
# 5                  Connected to an open-source project    6.0
# 6                          Good brand and public image    7.0
# 7                          Reliability and low latency    8.0
# 8                                 Costs are manageable    9.0
# 9                              Other (please specify):   10.0
# 10                      Other (please specify): - Text   13.0
# 11                             Lack of AI or AI agents    1.0
# 12                                      Poor usability    2.0
# 13                              Lack of or sub-par API    3.0
# 14                          Inefficient or time-costly    4.0
# 15                                 Prohibitive pricing    5.0
# 16                        Security or privacy concerns    6.0
# 17                 Availability of better alternatives    7.0
# 18         Outdated or obsolete technology or features    8.0
# 19                                    Ethical concerns    9.0
# 20                             Other (please specify):   10.0
# 21                      Other (please specify): - Text   15.0
# 22       Control over the level of quality in projects    1.0
# 23         Autonomy and trust to manage your own tasks    2.0
# 24                               You like your manager    3.0
# 25               Collaboration and support from a team    4.0
# 26                                      Expert mentors    5.0
# 27   Opportunities to mentor and lead junior-level ...    6.0
# 28                    Developing specialized expertise    7.0
# 29                         Solving real-world problems    8.0
# 30   Job stability and career growth with a single ...    9.0
# 31   Innovation through solving challenging and com...   10.0
# 32             Working with new technologies and tools   11.0
# 33                        Competitive pay and benefits   12.0
# 34                Recognition from peers for your work   13.0
# 35           Recognition from leadership for your work   14.0
# 36                             Other (please specify):   15.0
# 37                      Other (please specify): - Text   15.0
# 38   Browse content related to Q&A posts I recently...    1.0
# 39   Read and/or vote on comments for a Question or...    2.0
# 40                     Bookmark posts to look at later    3.0
# 41   Directly open a Q&A post via search, documenta...    4.0
# 42                                      Ask a question    5.0
# 43                                   Answer a question    6.0
# 44                                Comment on Q&A posts    7.0
# 45                           Upvote/Downvote Q&A posts    8.0
# 46                      Use discussion or chat feature    9.0
# 47                                   Other (write in):   10.0
# 48                            Other (write in): - Text   15.0
# 49                                                 NaN    NaN
# 50                                                 NaN    NaN
# 51                                                 NaN    NaN
# 52                                                 NaN    NaN
# 53                                                 NaN    NaN
# 54                                                 NaN    NaN
# 55                                                 NaN    NaN
# 56                                                 NaN    NaN
# 57                                                 NaN    NaN
# 58                                                 NaN    NaN
# 59                                                 NaN    NaN
# 60                                                 NaN    NaN
# 61                                                 NaN    NaN
# 62                                                 NaN    NaN
# 63                                                 NaN    NaN
# 64                                                 NaN    NaN
# 65                                                 NaN    NaN
# 66                                                 NaN    NaN
# 67                                                 NaN    NaN
# 68                                                 NaN    NaN
# 69                                                 NaN    NaN
# 70                                                 NaN    NaN
# 71                                                 NaN    NaN
# 72                                                 NaN    NaN
# 73                                                 NaN    NaN
# 74                                                 NaN    NaN
# 75                                                 NaN    NaN
# 76                                                 NaN    NaN
# 77                                                 NaN    NaN
# 78                                                 NaN    NaN
# 79                                                 NaN    NaN
# 80                                                 NaN    NaN
# 81                                                 NaN    NaN
# 82                                                 NaN    NaN
# 83                                                 NaN    NaN
# 84                                                 NaN    NaN
# 85                                                 NaN    NaN
# 86                                                 NaN    NaN
# 87                                                 NaN    NaN
# 88                                                 NaN    NaN
# 89                                                 NaN    NaN
# 90                                                 NaN    NaN
# 91                                                 NaN    NaN
# 92                                                 NaN    NaN
# 93                                                 NaN    NaN
# 94                                                 NaN    NaN
# 95                                                 NaN    NaN
# 96                                                 NaN    NaN
# 97                                                 NaN    NaN
# 98                                                 NaN    NaN
# 99                                                 NaN    NaN
# 100                                                NaN    NaN
# 101                                                NaN    NaN
# 102                                                NaN    NaN
# 103                                                NaN    NaN
# 104                                                NaN    NaN
# 105                                                NaN    NaN
# 106                                                NaN    NaN
# 107                                                NaN    NaN
# 108                                                NaN    NaN
# 109                                                NaN    NaN
# 110                                                NaN    NaN
# 111                                                NaN    NaN
# 112                                                NaN    NaN
# 113                                                NaN    NaN
# 114                                                NaN    NaN
# 115                                                NaN    NaN
# 116                                                NaN    NaN
# 117                                                NaN    NaN
# 118                                                NaN    NaN
# 119                                                NaN    NaN
# 120                                                NaN    NaN
# 121                                                NaN    NaN
# 122                                                NaN    NaN
# 123                                                NaN    NaN
# 124                                                NaN    NaN
# 125                                                NaN    NaN
# 126                                                NaN    NaN
# 127                                                NaN    NaN
# 128                                                NaN    NaN
# 129                                                NaN    NaN
# 130                                                NaN    NaN
# 131                                                NaN    NaN
# 132                                                NaN    NaN
# 133                                                NaN    NaN
# 134                                                NaN    NaN
# 135                                                NaN    NaN
# 136                                                NaN    NaN
# 137                                                NaN    NaN
# 138                                                NaN    NaN

# %%
123456
# Out:
# 123456

# %% [markdown]
# # Title

# %% [markdown]
# # Title

# %% [markdown]
# ## Subtitle

# %% [markdown]
# hi

# %% [raw]
# 9999

# %%
"hi World"

# %%
print("Hello world!")
# Out:
# Hello world!

# %%
# printing my first message
"Hello world!"
# Out:
# 'Hello world!'

# %%
type("Hello World")
# Out:
# str

# %%
"Hello world!".upper()
# Out:
# 'HELLO WORLD!'
