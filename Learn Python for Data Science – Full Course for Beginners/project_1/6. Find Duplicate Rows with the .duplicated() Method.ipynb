# %%
import pandas as pd

# %%
df_laptops = pd.read_csv('laptop_price.csv')

# %%
df_laptops.head(3)
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz  8GB            128GB SSD
# 1        Intel Core i5 1.8GHz  8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz  8GB            256GB SSD
#
#                             Gpu  OpSys  Weight       Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg  71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg  47895.5232
# 2         Intel HD Graphics 620  No OS  1.86kg  30636.0000

# %%
df_laptops = df_laptops.rename(columns={'Unnamed: 0': "laptop_ID"})

# %%
df_laptops['laptop_ID'] = [i for i in range(1,1304)]

# %%
df_laptops
# Out:
#       laptop_ID Company            TypeName  Inches  \
# 0             1   Apple           Ultrabook    13.3
# 1             2   Apple           Ultrabook    13.3
# 2             3      HP            Notebook    15.6
# 3             4   Apple           Ultrabook    15.4
# 4             5   Apple           Ultrabook    13.3
# ...         ...     ...                 ...     ...
# 1298       1299  Lenovo  2 in 1 Convertible    14.0
# 1299       1300  Lenovo  2 in 1 Convertible    13.3
# 1300       1301  Lenovo            Notebook    14.0
# 1301       1302      HP            Notebook    15.6
# 1302       1303    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %% [markdown]
# # 1 duplicated()

# %% [markdown]
# ## 1.1 Examle 1

# %%
# Find duplcaes in 1 column/series
df_laptops.duplicated('laptop_ID')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1298    False
# 1299    False
# 1300    False
# 1301    False
# 1302    False
# Length: 1303, dtype: bool

# %%
# show elements in dataframe with duplicates column 'laptop_ID'
df_laptops[df_laptops.duplicated('laptop_ID')]
# Out:
# Empty DataFrame
# Columns: [laptop_ID, Company, TypeName, Inches, ScreenResolution, Cpu, Ram, Memory, Gpu, OpSys, Weight, Price]
# Index: []

# %%
# duplicaes in 2 or more columns
df_laptops[df_laptops.duplicated(['Company', 'TypeName', 'Inches'])]
# Out:
#       laptop_ID Company            TypeName  Inches  \
# 1             2   Apple           Ultrabook    13.3
# 4             5   Apple           Ultrabook    13.3
# 6             7   Apple           Ultrabook    15.4
# 7             8   Apple           Ultrabook    13.3
# 10           11      HP            Notebook    15.6
# ...         ...     ...                 ...     ...
# 1298       1299  Lenovo  2 in 1 Convertible    14.0
# 1299       1300  Lenovo  2 in 1 Convertible    13.3
# 1300       1301  Lenovo            Notebook    14.0
# 1301       1302      HP            Notebook    15.6
# 1302       1303    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 1                                       1440x900
# 4             IPS Panel Retina Display 2560x1600
# 6             IPS Panel Retina Display 2880x1800
# 7                                       1440x900
# 10                                      1366x768
# ...

# %%
df_laptops[df_laptops.duplicated(['Company', 'TypeName', 'Inches'])].sort_values(['Company', 'TypeName'])
# Out:
#       laptop_ID  Company            TypeName  Inches  \
# 234         235     Acer  2 in 1 Convertible    13.3
# 413         414     Acer  2 in 1 Convertible    13.3
# 619         620     Acer  2 in 1 Convertible    11.6
# 706         707     Acer  2 in 1 Convertible    13.3
# 959         960     Acer  2 in 1 Convertible    11.6
# ...         ...      ...                 ...     ...
# 1118       1119  Toshiba           Ultrabook    13.3
# 791         792     Vero            Notebook    14.0
# 1041       1042     Vero            Notebook    14.0
# 514         515   Xiaomi            Notebook    15.6
# 877         878   Xiaomi           Ultrabook    13.3
#
#                                ScreenResolution  \
# 234   IPS Panel Full HD / Touchscreen 1920x1080
# 413   IPS Panel Full HD / Touchscreen 1920x1080
# 619              IPS Panel Touchscreen 1366x768
# 706   IPS Panel Full HD / Touchscreen 1920x1080
# 959              IPS Panel Touchscreen 1366x768
# ...

# %% [markdown]
# ## 1.2 Example 2

# %% [markdown]
# ##### Task: Find the cheapest and most expensive laptop of each company using the sort_values() and duplicated() methods (keep "first", "last" and False)

# %%
# sort dataframe asending by and price
# cheapest first and most expensive last
df_laptops = df_laptops.sort_values(['Company', 'Price'])
df_laptops
# Out:
#       laptop_ID Company   TypeName  Inches             ScreenResolution  \
# 1215       1216    Acer    Netbook    11.6                     1366x768
# 290         291    Acer   Notebook    15.6                     1366x768
# 1102       1103    Acer   Notebook    15.6                     1366x768
# 695         696    Acer    Netbook    11.6                     1366x768
# 1198       1199    Acer   Notebook    15.6                     1366x768
# ...         ...     ...        ...     ...                          ...
# 191         192    Vero   Notebook    14.0  IPS Panel Full HD 1920x1080
# 877         878  Xiaomi  Ultrabook    13.3  IPS Panel Full HD 1920x1080
# 192         193  Xiaomi  Ultrabook    13.3  IPS Panel Full HD 1920x1080
# 184         185  Xiaomi   Notebook    15.6  IPS Panel Full HD 1920x1080
# 514         515  Xiaomi   Notebook    15.6  IPS Panel Full HD 1920x1080
#
#                                        Cpu   Ram              Memory  \
# ...

# %%
# check all value categories in "Comany" column 
df_laptops.value_counts('Company')
# Out:
# Company
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Mediacom       7
# Razer          7
# Microsoft      6
# Vero           4
# Xiaomi         4
# Chuwi          3
# Fujitsu        3
# LG             3
# Google         3
# Huawei         2
# Name: count, dtype: int64

# %%
# duplicated values in "Company" columns (default -> keep='first')
duplicated_first = df_laptops.duplicated('Company', keep='first')

# %%
# show dataframe with duplicated values in "Company" column
df_laptops[duplicated_first]

# keep='first' (cheapst laptop per company)
# show dataframe with non duplicated values in "Company" column
df_laptops[~duplicated_first][['Company', 'Price']]

# check all value categories
df_laptops[~duplicated_first].value_counts('Company')
# Out:
# Company
# Acer         1
# Apple        1
# Asus         1
# Chuwi        1
# Dell         1
# Fujitsu      1
# Google       1
# HP           1
# Huawei       1
# LG           1
# Lenovo       1
# MSI          1
# Mediacom     1
# Microsoft    1
# Razer        1
# Samsung      1
# Toshiba      1
# Vero         1
# Xiaomi       1
# Name: count, dtype: int64

# %%
# keep='last'
duplicated_last = df_laptops.duplicated('Company', keep='last')
# keep=False
duplicated_false = df_laptops.duplicated('Company', keep=False)

# %%
# keep='last'(most expensive laptop per company)
# show datafrmae with non duplicated values in "Company" column
df_laptops[~duplicated_last][['Company', 'Price']]
# Out:
#         Company       Price
# 1189       Acer  138474.720
# 17        Apple  152274.240
# 1066       Asus  211788.000
# 421       Chuwi   23922.720
# 723        Dell  194972.832
# 623     Fujitsu   42570.720
# 437      Google  117162.720
# 749          HP  233845.920
# 214      Huawei   79866.720
# 678          LG  122490.720
# 610      Lenovo  261018.720
# 177         MSI  149130.720
# 580    Mediacom   20725.920
# 449   Microsoft  137941.920
# 196       Razer  324954.720
# 874     Samsung   98514.720
# 491     Toshiba  149130.720
# 191        Vero   13852.800
# 514      Xiaomi   74589.336

# %%
# keep=False
# shor dataframe with non fuplicated values in "Company" column
df_laptops[~duplicated_false]
# Out:
# Empty DataFrame
# Columns: [laptop_ID, Company, TypeName, Inches, ScreenResolution, Cpu, Ram, Memory, Gpu, OpSys, Weight, Price]
# Index: []

# %%
# all elements in company column are repeated at least once
df_laptops.value_counts('Company')
# Out:
# Company
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Mediacom       7
# Razer          7
# Microsoft      6
# Vero           4
# Xiaomi         4
# Chuwi          3
# Fujitsu        3
# LG             3
# Google         3
# Huawei         2
# Name: count, dtype: int64
