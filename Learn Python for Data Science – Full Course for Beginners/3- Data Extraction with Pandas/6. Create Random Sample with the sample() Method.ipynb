# %%
import pandas as pd

# %%
# reads csv file
df =  pd.read_csv('players_20.csv')
#set index
df.set_index('short_name', inplace=True)
# selecr column
df = df[['long_name', 'age', 'dob', 'height_cm', 'weight_kg', 'nationality', 'club']]

# %%
df
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
# E. Hazard                                  Eden Hazard   28  1991-01-07
# ...                                                ...  ...         ...
# Shao Shuai                                          邵帅   22  1997-03-10
# Xiao Mingjie                              Mingjie Xiao   22  1997-01-01
# Zhang Wei                                           张威   19  2000-05-16
# Wang Haijian                                       汪海健   18  2000-08-02
# Pan Ximing                                         潘喜明   26  1993-01-11
#
#                    height_cm  weight_kg nationality  \
# short_name
# L. Messi                 170         72   Argentina
# Cristiano Ronaldo        187         83    Portugal
# Neymar Jr                175         68      Brazil
# J. Oblak                 188         87    Slovenia
# E. Hazard                175         74     Belgium
# ...                      ...        ...         ...
# Shao Shuai               186         79    China PR
# Xiao Mingjie             177         66    China PR
# Zhang Wei                186         75    China PR
# Wang Haijian             185         74    China PR
# Pan Ximing               182         78    China PR
#
#                                             club
# short_name
# L. Messi                            FC Barcelona
# Cristiano Ronaldo                       Juventus
# Neymar Jr                    Paris Saint-Germain
# J. Oblak                         Atlético Madrid
# E. Hazard                            Real Madrid
# ...                                          ...
# Shao Shuai                      Beijing Renhe FC
# Xiao Mingjie                    Shanghai SIPG FC
# Zhang Wei                 Hebei China Fortune FC
# Wang Haijian       Shanghai Greenland Shenhua FC
# Pan Ximing                Hebei China Fortune FC
#
# [18278 rows x 7 columns]

# %% [markdown]
# # 1 sample()

# %%
# extract 10 random elements from the "nationality" column
df['nationality'].sample(10, random_state=99)
# Out:
# short_name
# R. Alvarado               Mexico
# Qiao Wei                China PR
# E. Paredes                 Chile
# K. Stoyanov             Bulgaria
# M. Chudý                Slovakia
# D. Sundaram                India
# R. Gagliardini             Italy
# G. Debeljuh              Croatia
# Kim Seung Yong    Korea Republic
# M. Hansen                Denmark
# Name: nationality, dtype: object

# %%
# extract a random 20% sample of the dataframe
df.sample(int(18278 * 20 / 100))
# Out:
#                                   long_name  age         dob  height_cm  \
# short_name
# D. Davis                        David Davis   28  1991-02-20        177
# D. Volkmer                  Dominic Volkmer   23  1996-04-27        194
# M. Paes                        Maarten Paes   21  1998-05-14        191
# Park Byung Hyun         박병현 Byung Hyun Park   26  1993-03-28        184
# D. Hernández               Daniel Hernández   28  1990-12-01        176
# ...                                     ...  ...         ...        ...
# Hugo Rubiães     Hugo Adryan Rubiães Chaves   35  1984-02-29        175
# D. Lenihan                  Darragh Lenihan   25  1994-03-16        178
# M. Wdowiak                  Mateusz Wdowiak   22  1996-08-28        174
# E. Taşdemir                   Emre Taşdemir   23  1995-08-08        176
# M. Osman                     Mohammed Osman   25  1994-01-01        183
#
#                  weight_kg          nationality                  club
# short_name
# D. Davis                82              England       Birmingham City
# D. Volkmer              88              Germany   SSV Jahn Regensburg
# M. Paes                 82          Netherlands            FC Utrecht
# Park Byung Hyun         83       Korea Republic              Daegu FC
# D. Hernández            65             Colombia       Deportivo Pasto
# ...                    ...                  ...                   ...
# Hugo Rubiães            75               Brazil            Fluminense
# D. Lenihan              76  Republic of Ireland      Blackburn Rovers
# M. Wdowiak              60               Poland              Cracovia
# E. Taşdemir             70               Turkey        Galatasaray SK
# M. Osman                78                Syria       Heracles Almelo
#
# [3655 rows x 7 columns]

# %%
df.sample(frac=0.2)
# Out:
#                                  long_name  age         dob  height_cm  \
# short_name
# G. Lefebvre              Grégoire Lefebvre   25  1994-05-13        174
# J. Baird                        Jack Baird   23  1996-02-07        188
# H. Opdal                Håkon Eikemo Opdal   37  1982-06-11        188
# B. Nimaga                    Bakary Nimaga   24  1994-12-06        189
# Raúl             Raúl Michel Melo da Silva   29  1989-11-04        187
# ...                                    ...  ...         ...        ...
# S. van der Lei          Stefan van der Lei   26  1993-03-05        186
# N. Blandi                   Nicolás Blandi   29  1990-01-13        181
# P. Digby                        Paul Digby   24  1995-02-02        195
# J. Pérez          Juan David Pérez Benítez   28  1991-03-23        178
# Juninho         Vitor Gomes Pereira Júnior   30  1989-01-08        171
#
#                 weight_kg  nationality                    club
# short_name
# G. Lefebvre            63       France       AS Nancy Lorraine
# J. Baird               68     Scotland              St. Mirren
# H. Opdal               91       Norway                SK Brann
# B. Nimaga              71         Mali            TSV Hartberg
# Raúl                   80       Brazil                SC Braga
# ...                   ...          ...                     ...
# S. van der Lei         79  Netherlands                FC Emmen
# N. Blandi              76    Argentina  San Lorenzo de Almagro
# P. Digby               70      England               Stevenage
# J. Pérez               72     Colombia          Millonarios FC
# Juninho                67       Brazil               LA Galaxy
#
# [3656 rows x 7 columns]

# %%
df.sample(frac=0.2, random_state=12)
# Out:
#                                long_name  age         dob  height_cm  \
# short_name
# Y. Thoelen               Yannick Thoelen   28  1990-07-18        188
# M. Nadé                     Mickaël Nadé   20  1999-03-04        188
# V. García   Víctor Hugo García Hernández   25  1994-06-11        178
# M. Gyamfi                 Maxwell Gyamfi   19  2000-01-18        185
# W. Cyprien                 Wylan Cyprien   24  1995-01-28        180
# ...                                  ...  ...         ...        ...
# H. Kadish                  Hassan Kadish   26  1992-09-26        179
# A. Chapman                 Aaron Chapman   29  1990-05-29        203
# I. Ezekiel                  Imoh Ezekiel   25  1993-10-24        178
# H. Sakai                           酒井 宏樹   29  1990-04-12        183
# C. Keșerü          Claudiu Andrei Keșerü   32  1986-12-02        178
#
#             weight_kg   nationality                    club
# short_name
# Y. Thoelen         89       Belgium             KV Mechelen
# M. Nadé            80        France        AS Saint-Étienne
# V. García          71     Venezuela       Vitória Guimarães
# M. Gyamfi          75       Germany         VfL Bochum 1848
# W. Cyprien         75        France                OGC Nice
# ...               ...           ...                     ...
# H. Kadish          73  Saudi Arabia                Al Hilal
# A. Chapman         92       England     Peterborough United
# I. Ezekiel         70       Nigeria             KV Kortrijk
# H. Sakai           70         Japan  Olympique de Marseille
# C. Keșerü          71       Romania                 Romania
#
# [3656 rows x 7 columns]

# %%
# upsample: increase the sampling rate -> frac>1 (Note: replace parameter has to be True for frac parameter > 1)
df.sample(frac=2, replace=True)
# Out:
#                                 long_name  age         dob  height_cm  \
# short_name
# L. Hannant                   Luke Hannant   25  1993-11-04        180
# M. Ridenton              Matthew Ridenton   23  1996-03-11        180
# R. Cornwall                  Rob Cornwall   24  1994-10-16        183
# G. Williams   George Christopher Williams   23  1995-09-07        172
# G. Andronic             Gheorghe Andronic   27  1991-09-25        172
# ...                                   ...  ...         ...        ...
# K. Athiu                      Kenny Athiu   26  1992-08-05        201
# J. Toivio                    Joona Toivio   31  1988-03-10        186
# A. Letellier          Alexandre Letellier   28  1990-12-11        193
# G. Velázquez            Gustavo Velázquez   28  1991-04-17        180
# E. Ocansey                   Eric Ocansey   21  1997-08-22        173
#
#               weight_kg          nationality                 club
# short_name
# L. Hannant           70              England     Cambridge United
# M. Ridenton          72          New Zealand       Newcastle Jets
# R. Cornwall          86  Republic of Ireland          Bohemian FC
# G. Williams          73                Wales  Forest Green Rovers
# G. Andronic          63              Moldova        Astra Giurgiu
# ...                 ...                  ...                  ...
# K. Athiu             85          South Sudan    Melbourne Victory
# J. Toivio            87              Finland            BK Häcken
# A. Letellier         93               France      Sarpsborg 08 FF
# G. Velázquez         78             Paraguay            FC Juárez
# E. Ocansey           71                Ghana          KV Kortrijk
#
# [36556 rows x 7 columns]

# %%
18278  * 2
# Out:
# 36556

# %%
df.sample(frac=2, replace=True, random_state=77)
# Out:
#                          long_name  age         dob  height_cm  weight_kg  \
# short_name
# T. Costantini   Tommaso Costantini   23  1996-06-23        183         77
# M. Dimun               Milan Dimun   22  1996-09-19        186         76
# J. Bjørdal     Johan Lædre Bjørdal   33  1986-05-05        188         83
# W. Ditta              Willer Ditta   22  1997-01-23        180         80
# Y. Çetin       Yıldırım Mert Çetin   22  1997-01-01        189         85
# ...                            ...  ...         ...        ...        ...
# C. Karayel         Cebrail Karayel   24  1994-08-15        174         75
# Yang Shiyuan                   杨世元   25  1994-03-11        173         70
# H. Ishikawa                  石川 启人   20  1998-07-16        172         64
# I. Slimani           Islam Slimani   31  1988-06-18        188         83
# Róber          Roberto Suárez Pier   24  1995-02-16        182         74
#
#               nationality                    club
# short_name
# T. Costantini       Italy                    SPAL
# M. Dimun         Slovakia                Cracovia
# J. Bjørdal         Norway       Vålerenga Fotball
# W. Ditta         Colombia               Junior FC
# Y. Çetin           Turkey                    Roma
# ...                   ...                     ...
# C. Karayel         Turkey          MKE Ankaragücü
# Yang Shiyuan     China PR        Shanghai SIPG FC
# H. Ishikawa         Japan              Sagan Tosu
# I. Slimani        Algeria          Leicester City
# Róber               Spain  Deportivo de La Coruña
#
# [36556 rows x 7 columns]
