# %%
print("Hello world!".upper())
print("Hello world!".lower())
print("Hello world!".title())
# Out:
# HELLO WORLD!
# hello world!
# Hello World!

# %%
"Hello world!".count('l')
# Out:
# 3

# %%
"Hello world!".replace('o', 'u')
# Out:
# 'Hellu wurld!'

# %%
message_1 = "I'm learning Python"

# %%
message_1
# Out:
# "I'm learning Python"

# %%
message_2 = "and it's fun!"

# %%
message_2
# Out:
# "and it's fun!"

# %%
'I\'m learning Python'
# Out:
# "I'm learning Python"

# %%
message = message_1 + " " + message_2
message
# Out:
# "I'm learning Python and it's fun!"

# %%
f'{message_1} abc {message_2}'
# Out:
# "I'm learning Python abc and it's fun!"

# %%
countries = ["United States", "Canada", "China", "Brazil"]

# %%
countries
# Out:
# ['United States', 'Canada', 'China', 'Brazil']

# %%
print(countries[0])
print(countries[1])
print(countries[2])
# Out:
# United States
# Canada
# China

# %%
countries[-4]
# Out:
# 'United States'

# %%
countries[:-1]
# Out:
# ['United States', 'Canada', 'China']

# %%
countries
# Out:
# ['United States', 'Canada', 'China', 'Brazil']

# %%
countries.append('India')

# %%
countries
# Out:
# ['United States', 'Canada', 'China', 'Brazil', 'India']

# %%
countries.insert(0, 'Spain')

# %%
countries
# Out:
# ['Spain', 'United States', 'Canada', 'China', 'Brazil', 'India']

# %%
countries_2 = ['UK', 'Germany', 'Ausralia']

# %%
countries + countries_2
# Out:
# ['Spain',
#  'United States',
#  'Canada',
#  'China',
#  'Brazil',
#  'India',
#  'UK',
#  'Germany',
#  'Ausralia']

# %%
nested_list = [countries, countries_2]
nested_list
# Out:
# [['Spain', 'United States', 'Canada', 'China', 'Brazil', 'India'],
#  ['UK', 'Germany', 'Ausralia']]

# %%
countries.remove('United States')

# %%
countries
# Out:
# ['Spain', 'Canada', 'China', 'Brazil', 'India']

# %%
countries.pop(-1)
# Out:
# 'India'

# %%
countries
# Out:
# ['Spain', 'Canada', 'China', 'Brazil']

# %%
del countries[0]

# %%
countries
# Out:
# ['Canada', 'China', 'Brazil']

# %%
numbers = [4, 3, 10, 7, 1, 2]

# %%
numbers.sort()

# %%
numbers
# Out:
# [1, 2, 3, 4, 7, 10]

# %%
numbers.sort(reverse=True)
numbers
# Out:
# [10, 7, 4, 3, 2, 1]

# %% [markdown]
# # 4.0.4 Update an Element

# %%
numbers[0] = 1000
new_list = numbers

# %% [markdown]
# # 4.0.5 Coping a list

# %%
countries[:]
# Out:
# ['Canada', 'China', 'Brazil']

# %%
new_list
# Out:
# [1000, 7, 4, 3, 2, 1]

# %%
new_list_2 = countries.copy()

# %%
new_list_2
# Out:
# ['Canada', 'China', 'Brazil']

# %% [markdown]
# # 5 Dictionary

# %%
my_dict = {'key1': 'value1', 'key2': 'value2', }

# %%
my_data = {'name': 'Frank', 'age': 26}

# %%
my_data
# Out:
# {'name': 'Frank', 'age': 26}

# %%
my_data.keys()
# Out:
# dict_keys(['name', 'age'])

# %%
my_data.values()
# Out:
# dict_values(['Frank', 26])

# %%
my_data.items()
# Out:
# dict_items([('name', 'Frank'), ('age', 26)])

# %%
my_data['height'] = 1.7
my_data
# Out:
# {'name': 'Frank', 'age': 26, 'height': 1.7}

# %%
my_data.update({'height': 1.8})
my_data
# Out:
# {'name': 'Frank', 'age': 26, 'height': 1.8}

# %% [markdown]
# # 5.0.1 Coopy a dictionary

# %%
new_dict = my_data
new_dict
# Out:
# {'name': 'Frank', 'age': 26, 'height': 1.8}

# %% [markdown]
# # 5.0.2 Rmove Element

# %%
my_data.pop('name')
# Out:
# 'Frank'

# %%
my_data
# Out:
# {'age': 26, 'height': 1.8}

# %%
del my_data['age']

# %%
my_data
# Out:
# {'height': 1.8}

# %%
my_data.clear()
my_data
# Out:
# {}

# %% [markdown]
# # 6 If Statment

# %%
age = 20

if age >= 18:
    print("You're an adult!")
elif age >= 13:
    prit("You're a teenager")
else:
    print("You're a kid")
# Out:
# You're an adult!

# %% [markdown]
# # 7 For Loop

# %%
countries
# Out:
# ['Canada', 'China', 'Brazil']

# %%
for country in countries:
    print(country)
# Out:
# Canada
# China
# Brazil

# %%
for i, country in enumerate(countries):
    print(i)
    print(country)
# Out:
# 0
# Canada
# 1
# China
# 2
# Brazil

# %%
my_data = {'name': 'Frank', 'age': 26}
my_data
# Out:
# {'name': 'Frank', 'age': 26}

# %%
for key, value in my_data.items():
    print(key)
    print(value)
# Out:
# name
# Frank
# age
# 26

# %% [markdown]
# # 8 Function

# %%
def sum_values(a, b):
    return a + b

# %%
sum_values(1, 3)
# Out:
# 4

# %% [markdown]
# #

# %% [markdown]
# # Buit-in Function

# %%
countries = ['Canada', 'Egypt', 'Chaina', 'Spain']

# %%
len(countries)
# Out:
# 4

# %%
max([10, 63, 81, 1, 99])
# Out:
# 1

# %%
min([10, 63, 81, 1, 99])
# Out:
# 1

# %%
type(countries)
# Out:
# list

# %%
for i in range(1, 10, 2):
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %% [markdown]
# # 9.1 OS Module

# %%
import os

# %%
os.getcwd()
# Out:
# 'D:\\project\\Pandas Tutorials'

# %% [raw]
# os.listdir()

# %%
os.makedirs("Neeeeeeeew Folde")

# %%
os.listdir()
# Out:
# ['.idea',
#  '.ipynb_checkpoints',
#  'jupyter_notebook',
#  'Neeeeeeeew Folde',
#  'pandas_tutorials_venv',
#  'python_for_data_science.ipynb']
