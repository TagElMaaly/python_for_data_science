# %%
import pandas as pd

# %%
# reading the csv file
df_exams = pd.read_csv('StudentsPerformance.csv')
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# # 1 Create Index

# %%
import numpy as np
import random

# %%
# createing non repetitive values for the index
new_index = np.arange(0, 1000)

# %%
# shuffling the indexes
random.shuffle(new_index)

# %%
# create a new column with new index
df_exams['new_index'] = new_index
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      new_index
# 0          914
# 1          226
# 2          132
# 3          293
# 4          759
# ..         ...
# 995        173
# 996        485
# 997        929
# 998        213
# 999        772
#
# [1000 rows x 9 columns]

# %% [markdown]
# # 2 Set Index

# %%
# set new_index column as index
df_exams.set_index('new_index', inplace=True)
df_exams
# Out:
#            gender race/ethnicity parental level of education         lunch  \
# new_index
# 914        female        group B           bachelor's degree      standard
# 226        female        group C                some college      standard
# 132        female        group B             master's degree      standard
# 293          male        group A          associate's degree  free/reduced
# 759          male        group C                some college      standard
# ...           ...            ...                         ...           ...
# 173        female        group E             master's degree      standard
# 485          male        group C                 high school  free/reduced
# 929        female        group C                 high school  free/reduced
# 213        female        group D                some college      standard
# 772        female        group D                some college  free/reduced
#
#           test preparation course  math score  reading score  writing score
# new_index
# 914                          none          72             72             74
# 226                     completed          69             90             88
# 132                          none          90             95             93
# 293                          none          47             57             44
# 759                          none          76             78             75
# ...                           ...         ...            ...            ...
# 173                     completed          88             99             95
# 485                          none          62             55             55
# 929                     completed          59             71             65
# 213                     completed          68             78             77
# 772                          none          77             86             86
#
# [1000 rows x 8 columns]

# %% [markdown]
# # 3 Sort Index

# %%
# sort dataframe by new index
df_exams.sort_index()
# Out:
#            gender race/ethnicity parental level of education         lunch  \
# new_index
# 0          female        group E          associate's degree      standard
# 1            male        group B            some high school      standard
# 2            male        group D                 high school      standard
# 3            male        group B          associate's degree      standard
# 4            male        group C                 high school      standard
# ...           ...            ...                         ...           ...
# 995        female        group C                 high school      standard
# 996          male        group C                some college  free/reduced
# 997          male        group B                some college      standard
# 998          male        group C                some college      standard
# 999        female        group D                 high school      standard
#
#           test preparation course  math score  reading score  writing score
# new_index
# 0                            none          59             62             69
# 1                            none          68             54             53
# 2                            none          72             66             66
# 3                            none          80             76             64
# 4                       completed          86             81             80
# ...                           ...         ...            ...            ...
# 995                          none          60             68             72
# 996                          none          80             64             66
# 997                          none          62             61             57
# 998                     completed          79             79             78
# 999                     completed          69             77             78
#
# [1000 rows x 8 columns]

# %%
# sort desending by index
df_exams.sort_index(ascending=False, inplace=True)
df_exams
# Out:
#            gender race/ethnicity parental level of education         lunch  \
# new_index
# 999        female        group D                 high school      standard
# 998          male        group C                some college      standard
# 997          male        group B                some college      standard
# 996          male        group C                some college  free/reduced
# 995        female        group C                 high school      standard
# ...           ...            ...                         ...           ...
# 4            male        group C                 high school      standard
# 3            male        group B          associate's degree      standard
# 2            male        group D                 high school      standard
# 1            male        group B            some high school      standard
# 0          female        group E          associate's degree      standard
#
#           test preparation course  math score  reading score  writing score
# new_index
# 999                     completed          69             77             78
# 998                     completed          79             79             78
# 997                          none          62             61             57
# 996                          none          80             64             66
# 995                          none          60             68             72
# ...                           ...         ...            ...            ...
# 4                       completed          86             81             80
# 3                            none          80             76             64
# 2                            none          72             66             66
# 1                            none          68             54             53
# 0                            none          59             62             69
#
# [1000 rows x 8 columns]
